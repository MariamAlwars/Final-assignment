# %%
#add and modify are fixed 
import tkinter as tk
import tkinter.messagebox as messagebox
import pickle
from tkinter import ttk, Button
from datetime import date
from datetime import datetime
from enum import Enum
import os



ID_List=[]
class Department(Enum):
    ACCOUNTING = "Accounting"
    IT = "Information Technology"
    MANUFACTURING = "Manufacturing"
    SALES = "Sales"
    MARKETING = "Marketing"
    HR = "Human Resources"
    ADMINISTRATION = "Administration"
    FINANCE = "Finance"
    OPERATIONS = "Operations"
    CUSTOMER_SERVICE = "Customer Service"
    PROCUREMENT = "Procurement"
    QUALITY_ASSURANCE = "Quality Assurance"

class JobTitle(Enum):
    MANAGER = "Manager"
    SALES_PERSON = "Salesperson"
    RECEPTIONIST = "Receptionist"
    MECHANIC = "Mechanic"
    ACCOUNTANT = "Accountant"
    MARKETING_SPECIALIST = "Marketing Specialist"
    HR_OFFICER = "HR Officer"
    IT_SPECIALIST = "IT Specialist"
    ADMINISTRATOR = "Administrator"
    DRIVER = "Driver"

class Gender(Enum):
    MALE = 'Male'
    FEMALE = 'Female'







class Employee:
    def __init__(self, firstName, lastName, gender, dateOfBirth, contactNumber, emailAddress, ID, department, jobTitle, basicSalary):
        self._firstName = firstName
        self._lastName = lastName
        self._gender = gender
        self._dateOfBirth = datetime.strptime(dateOfBirth, "%Y-%m-%d").date()
        self._contactNumber = contactNumber
        self._emailAddress = emailAddress
        self._age = self.calculateAge()
        self._ID = ID
        self._department = department
        self._jobTitle = jobTitle
        self._basicSalary = basicSalary
        self._customers = []
        self.employees = []


    def calculateAge(self):
        today = date.today()
        age = today.year - self._dateOfBirth.year
        if today.month < self._dateOfBirth.month or (
                today.month == self._dateOfBirth.month and today.day < self._dateOfBirth.day):
            age -= 1
        return age


class Car:
    def __init__(self, carID, price, carType, fuelCapacity, maxSpeed, color, mileage, is_new):
        self._carID = carID
        self._price = price
        self._carType = carType
        self._fuelCapacity = fuelCapacity
        self._maxSpeed = maxSpeed
        self._color = color
        self._mileage = mileage
        self._is_new = is_new

class CarSalesGUI:
    def __init__(self):
        self.root = tk.Tk()
        self.tabControl = ttk.Notebook(self.root)
        self.tabControl.pack(expand=1, fill="both")
        self.create_main_tab()
        self.employees = []
        self.root.mainloop()

    def create_main_tab(self):
        # Create the main tab
        main_tab = ttk.Frame(self.tabControl)
        self.tabControl.add(main_tab, text="Main")

        # Create a label and combobox for selecting an option
        label_option = tk.Label(main_tab, text="Select an option:")
        label_option.pack()

        combo_option = ttk.Combobox(main_tab, values=["Modify Employee", "Delete Employee", "Add Employee",
                                                      "Display Car Details", "Sales Details"])
        combo_option.pack()

        # Create a button to trigger the selected option
        button_execute = tk.Button(main_tab, text="Execute", command=lambda: self.execute_option(combo_option.get()))
        button_execute.pack()

    def execute_option(self, option):
        if option == "Modify Employee":
            self.create_modify_employee_tab()
        elif option == "Delete Employee":
            self.create_delete_employee_tab()
        elif option == "Add Employee":
            self.create_add_employee_tab()
        elif option == "Display Car Details":
            self.create_display_car_details_tab()
        elif option == "Sales Details":
            self.create_sales_details_tab()

    def create_modify_employee_tab(self):
        # Create the modify employee tab
        modify_employee_window = tk.Toplevel(self.root)
        modify_employee_window.title("Modify Employee")

        add_employee_window = ttk.LabelFrame(modify_employee_window, text="Add Employee")
        add_employee_window.pack(padx=10, pady=10)

        # First Name
        ttk.Label(add_employee_window, text="First Name:").grid(column=0, row=0)
        self.first_name_entry = ttk.Entry(add_employee_window, width=30)
        self.first_name_entry.grid(column=1, row=0)

        # Last Name
        ttk.Label(add_employee_window, text="Last Name:").grid(column=0, row=1)
        self.last_name_entry = ttk.Entry(add_employee_window, width=30)
        self.last_name_entry.grid(column=1, row=1)

        # Gender
        ttk.Label(add_employee_window, text="Gender:").grid(column=0, row=2)
        self.gender_combobox = ttk.Combobox(add_employee_window, values=[gender.value for gender in Gender])
        self.gender_combobox.grid(column=1, row=2)

        # Date of Birth
        ttk.Label(add_employee_window, text="Date of Birth (YYYY-MM-DD):").grid(column=0, row=3)
        self.dob_entry = ttk.Entry(add_employee_window, width=30)
        self.dob_entry.grid(column=1, row=3)

        # Contact Number
        ttk.Label(add_employee_window, text="Contact Number:").grid(column=0, row=4)
        self.contact_entry = ttk.Entry(add_employee_window, width=30)
        self.contact_entry.grid(column=1, row=4)

        # Email Address
        ttk.Label(add_employee_window, text="Email Address:").grid(column=0, row=5)
        self.email_entry = ttk.Entry(add_employee_window, width=30)
        self.email_entry.grid(column=1, row=5)

        # ID
        ttk.Label(add_employee_window, text="ID:").grid(column=0, row=6)
        self.id_entry = ttk.Entry(add_employee_window, width=30)
        self.id_entry.grid(column=1, row=6)

        # Department
        ttk.Label(add_employee_window, text="Department:").grid(column=0, row=7)
        self.department_combobox = ttk.Combobox(add_employee_window,
                                                values=[department.value for department in Department])
        self.department_combobox.grid(column=1, row=7)

        # Job Title
        ttk.Label(add_employee_window, text="Job Title:").grid(column=0, row=8)
        self.job_title_combobox = ttk.Combobox(add_employee_window, values=[job_title.value for job_title in JobTitle])
        self.job_title_combobox.grid(column=1, row=8)

        # Basic Salary
        ttk.Label(add_employee_window, text="Basic Salary:").grid(column=0, row=9)
        self.basic_salary_entry = ttk.Entry(add_employee_window, width=30)
        self.basic_salary_entry.grid(column=1, row=9)

        # Create a button to modify the employee
        button_modify_employee = tk.Button(modify_employee_window, text="Modify Employee",
                                           command=lambda: self.modify_employee(self.first_name_entry.get(),
            self.last_name_entry.get(), self.gender_combobox.get(), self.dob_entry.get(),
            self.contact_entry.get(), self.email_entry.get(), self.id_entry.get(), self.department_combobox.get(),
            self.job_title_combobox.get(), self.basic_salary_entry.get()))
        button_modify_employee.pack()

    def create_delete_employee_tab(self):

        delete_employee_window = ttk.LabelFrame(self.tabControl, text="Delete Employee")
        delete_employee_window.pack(padx=10, pady=10)

        # Employee ID
        ttk.Label(delete_employee_window, text="Employee ID:").grid(column=0, row=0)
        self.employee_id_entry = ttk.Entry(delete_employee_window, width=30)
        self.employee_id_entry.grid(column=1, row=0)

        # Delete Employee Button
        delete_button = tk.Button(delete_employee_window, text="Delete Employee", command=self.delete_employee)
        delete_button.grid(columnspan=2, pady=10)

    def create_add_employee_tab(self):
        add_employee_window = ttk.LabelFrame(self.tabControl, text="Add Employee")
        add_employee_window.pack(padx=10, pady=10)

        # First Name
        ttk.Label(add_employee_window, text="First Name:").grid(column=0, row=0)
        self.first_name_entry = ttk.Entry(add_employee_window, width=30)
        self.first_name_entry.grid(column=1, row=0)

        # Last Name
        ttk.Label(add_employee_window, text="Last Name:").grid(column=0, row=1)
        self.last_name_entry = ttk.Entry(add_employee_window, width=30)
        self.last_name_entry.grid(column=1, row=1)

        # Gender
        ttk.Label(add_employee_window, text="Gender:").grid(column=0, row=2)
        self.gender_combobox = ttk.Combobox(add_employee_window, values=[gender.value for gender in Gender])
        self.gender_combobox.grid(column=1, row=2)

        # Date of Birth
        ttk.Label(add_employee_window, text="Date of Birth (YYYY-MM-DD):").grid(column=0, row=3)
        self.dob_entry = ttk.Entry(add_employee_window, width=30)
        self.dob_entry.grid(column=1, row=3)

        # Contact Number
        ttk.Label(add_employee_window, text="Contact Number:").grid(column=0, row=4)
        self.contact_entry = ttk.Entry(add_employee_window, width=30)
        self.contact_entry.grid(column=1, row=4)

        # Email Address
        ttk.Label(add_employee_window, text="Email Address:").grid(column=0, row=5)
        self.email_entry = ttk.Entry(add_employee_window, width=30)
        self.email_entry.grid(column=1, row=5)

        # ID
        ttk.Label(add_employee_window, text="ID:").grid(column=0, row=6)
        self.id_entry = ttk.Entry(add_employee_window, width=30)
        self.id_entry.grid(column=1, row=6)

        # Department
        ttk.Label(add_employee_window, text="Department:").grid(column=0, row=7)
        self.department_combobox = ttk.Combobox(add_employee_window,
                                                values=[department.value for department in Department])
        self.department_combobox.grid(column=1, row=7)

        # Job Title
        ttk.Label(add_employee_window, text="Job Title:").grid(column=0, row=8)
        self.job_title_combobox = ttk.Combobox(add_employee_window, values=[job_title.value for job_title in JobTitle])
        self.job_title_combobox.grid(column=1, row=8)

        # Basic Salary
        ttk.Label(add_employee_window, text="Basic Salary:").grid(column=0, row=9)
        self.basic_salary_entry = ttk.Entry(add_employee_window, width=30)
        self.basic_salary_entry.grid(column=1, row=9)

        # Add Employee Button

        # Create a frame for the button
        button_frame = tk.Frame(add_employee_window)
        button_frame.grid(columnspan=2, padx=10)


        # Create the button inside the frame
        button_add_employee = tk.Button(button_frame, text="Add Employee", command=lambda: self.add_employee(
            self.first_name_entry.get(), self.last_name_entry.get(), self.gender_combobox.get(), self.dob_entry.get(),
            self.contact_entry.get(), self.email_entry.get(), self.id_entry.get(), self.department_combobox.get(),
            self.job_title_combobox.get(), self.basic_salary_entry.get()))
        button_add_employee.pack(pady=10)




    def create_display_car_details_tab(self):
        # Create the display car details tab
        display_car_details_window = tk.Toplevel(self.root)
        display_car_details_window.title("Display Car Details")


        # Create a label and entry field for the car ID to display
        label_id = tk.Label(display_car_details_window, text="ID Number:")
        label_id.pack()
        entry_id = tk.Entry(display_car_details_window)
        entry_id.pack()

        # Create a button to display the car details
        button_display_car_details = tk.Button(display_car_details_window, text="Display Car Details",
                                               command=lambda: self.display_car_details(entry_id.get()))
        button_display_car_details.pack()
    def create_sales_details_tab(self):
        # Create the sales details tab
        sales_details_window = tk.Toplevel(self.root)
        sales_details_window.title("Sales Details")

        # Load the employees from the binary file
        employees = self.load_employees()

        # Find the employee with the provided ID number
        for employee in employees:
            if employee.id_number == id_number:
                # Show the sales details of the employee
                sales_details = ""
                for sale in employee.sales:
                    sales_details += f"Car Sold: {sale.car_name}\nSale Price: {sale.sale_price}\n\n"

                tk.messagebox.showinfo("Sales Details", sales_details)
                return


    def add_employee(self, firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress, ID, department, jobTitle, basicSalary):
        firstName = self.first_name_entry.get()
        lastName = self.last_name_entry.get()
        gender = Gender(self.gender_combobox.get())
        dateOfBirth = self.dob_entry.get()
        contactNumber = self.contact_entry.get()
        emailAddress = self.email_entry.get()
        ID = self.id_entry.get()
        department = Department(self.department_combobox.get())
        jobTitle = JobTitle(self.job_title_combobox.get())
        basicSalary = self.basic_salary_entry.get()
        ID_List.append(self.id_entry.get())

        # Create an Employee instance with the provided details
        employee = Employee(firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress, ID, department, jobTitle, basicSalary)

        # Save the employee to a binary file using Pickle
        # Load employees from the binary file
        try:
            with open("employees.pkl", "rb") as file:
                employees = []
                while True:
                    try:
                        employee = pickle.load(file)
                        employees.append(employee)
                    except EOFError:
                        break
                tk.messagebox.showinfo("Success", "Employee added successfully.")
                return employees
        except FileNotFoundError:
            return []

        # Show a success message
        tk.messagebox.showinfo("Success", "Employee added successfully.")

    def delete_employee(self):
        employee_id = self.employee_id_entry.get()
        # Rest of the code to delete the employee record

        # Create a new tab to display the message
        message_tab = ttk.Frame()
        message_label = tk.Label(message_tab, text="Employee deleted successfully.")
        message_label.pack()

        # Add the new tab to the GUI
        tabControl.add(message_tab, text="Alert")

        employee_id = self.employee_id_entry.get()

        # Get the current working directory
        current_dir = os.getcwd()

        # Construct the file path relative to the current directory
        file_path = os.path.join(current_dir, 'employees.txt')

        # Open the file
        with open(file_path, 'r') as file:
            lines = file.readlines()

        # Find the employee with the given ID
        for i in range(len(lines)):
            if lines[i].strip() == employee_id:
                # Remove the employee record (assuming each employee record spans three lines)
                del lines[i:i + 3]

                # Write the updated employee data back to the file
                with open(file_path, 'w') as file:
                    file.writelines(lines)

                tk.messagebox.showinfo("Employee deleted successfully.")
                return

        tk.messagebox.showinfo("Employee not found.")



    def modify_employee(self,firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress, ID, department, jobTitle, basicSalary):
        # Get the values from the entry fields
        first_name = self.first_name_entry.get()
        last_name = self.last_name_entry.get()
        gender = Gender(self.gender_combobox.get())
        date_of_birth = self.dob_entry.get()
        contact_number = self.contact_entry.get()
        email_address = self.email_entry.get()
        id_number = self.id_entry.get()
        department = Department(self.department_combobox.get())
        job_title = JobTitle(self.job_title_combobox.get())
        basic_salary = self.basic_salary_entry.get()

        employee = Employee(firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress, ID, department, jobTitle, basicSalary)

        if id_number in ID_List:
            tk.messagebox.showinfo("Modification Successful", "Employee modified successfully.")
        else:
            tk.messagebox.showinfo("There is no employee with this ID number")
        try:
            with open("employees.pkl", "rb") as file:
                employees = []
                while True:
                    try:
                        employee = pickle.load(file)
                        employees.append(employee)
                    except EOFError:
                        break
                employees.append(employee)  # Add the modified employee
                ID_List.append(self.id_entry.get())  # Add the ID to the ID_List
                with open("employees.pkl", "wb") as file:
                    for emp in employees:
                        pickle.dump(emp, file)  # Save the modified employee list
        except FileNotFoundError:
            tk.messagebox.showinfo("File Not Found", "The employee file does not exist.")


    def clear_entry_fields(self):
        # Clear all the entry fields
        entry_first_name.delete(0, tk.END)
        entry_last_name.delete(0, tk.END)
        entry_gender.delete(0, tk.END)
        entry_date_of_birth.delete(0, tk.END)
        entry_contact_number.delete(0, tk.END)
        entry_email_address.delete(0, tk.END)
        entry_id.delete(0, tk.END)
        entry_department.delete(0, tk.END)
        entry_job_title.delete(0, tk.END)
        entry_basic_salary.delete(0, tk.END)

    def load_employees(self):
        # Load employees from the binary file
        try:
            with open("employees.pkl", "rb") as file:
                employees = []
                while True:
                    try:
                        employee = pickle.load(file)
                        employees.append(employee)
                    except EOFError:
                        break
                return employees
        except FileNotFoundError:
            return []

    def save_employees(self, employees):
        # Save employees to the binary file
        with open("employees.pkl", "wb") as file:
            for employee in employees:
                pickle.dump(employee, file)

    def load_cars(self):
        # Load cars from the binary file
        try:
            with open("cars.pkl", "rb") as file:
                cars = []
                while True:
                    try:
                        car = pickle.load(file)
                        cars.append(car)
                    except EOFError:
                        break
                return cars
        except FileNotFoundError:
            return []

    def save_cars(self, cars):
        # Save cars to the binary file
        with open("cars.pkl", "wb") as file:
            for car in cars:
                pickle.dump(car, file)


if __name__ == "__main__":
    CarSalesGUI()

# %%
'''
    def delete_employee(self):
        # Get the current working directory
        current_dir = os.getcwd()
        tk.messagebox.showinfo("Employee deleted successfully.")
        # Construct the file path relative to the current directory
        file_path = os.path.join(current_dir, 'employees.txt')

        # Open the file
        with open(file_path, 'r') as file:
            lines = file.readlines()

        # Find the employee with the given ID
        for i, line in enumerate(lines):
            if line.strip() == employee_id:
                # Remove the employee ID from the list
                del lines[i:i + 3]  # Assuming each employee record spans three lines

                # Write the updated employee data back to the file
                with open('employees.txt', 'w') as file:
                    file.writelines(lines)

                print("Employee deleted successfully.")
                return

        # Employee ID not found
        print("Employee not found.")
'''

# %%
import tkinter as tk
import tkinter.messagebox as messagebox
import pickle
from tkinter import ttk, Button
from datetime import date
from datetime import datetime
from enum import Enum
import os

EMPLOYEES_FILE = 'employees_data.pkl'
employees = []


class Department(Enum):
    ACCOUNTING = "Accounting"
    IT = "Information Technology"
    MANUFACTURING = "Manufacturing"
    SALES = "Sales"
    MARKETING = "Marketing"
    HR = "Human Resources"
    ADMINISTRATION = "Administration"
    FINANCE = "Finance"
    OPERATIONS = "Operations"
    CUSTOMER_SERVICE = "Customer Service"
    PROCUREMENT = "Procurement"
    QUALITY_ASSURANCE = "Quality Assurance"


class JobTitle(Enum):
    MANAGER = "Manager"
    SALES_PERSON = "Salesperson"
    RECEPTIONIST = "Receptionist"
    MECHANIC = "Mechanic"
    ACCOUNTANT = "Accountant"
    MARKETING_SPECIALIST = "Marketing Specialist"
    HR_OFFICER = "HR Officer"
    IT_SPECIALIST = "IT Specialist"
    ADMINISTRATOR = "Administrator"
    DRIVER = "Driver"


class Gender(Enum):
    MALE = 'Male'
    FEMALE = 'Female'


class Employee:
    def __init__(self, firstName, lastName, gender, dateOfBirth, contactNumber, emailAddress, ID, department, jobTitle,
                 basicSalary):
        self._firstName = firstName
        self._lastName = lastName
        self._gender = gender
        self._dateOfBirth = datetime.strptime(dateOfBirth, "%Y-%m-%d").date()
        self._contactNumber = contactNumber
        self._emailAddress = emailAddress
        self._age = self.calculateAge()
        self._ID = ID
        self._department = department
        self._jobTitle = jobTitle
        self._basicSalary = basicSalary
        self._customers = []

    def calculateAge(self):
        today = date.today()
        age = today.year - self._dateOfBirth.year
        if today.month < self._dateOfBirth.month or (
                today.month == self._dateOfBirth.month and today.day < self._dateOfBirth.day):
            age -= 1
        return age


class CarSalesGUI:
    def __init__(self):
        self.root = tk.Tk()
        self.tabControl = ttk.Notebook(self.root)
        self.tabControl.pack(expand=1, fill="both")
        self.create_main_tab()
        self.root.mainloop()
        self.employees = []
        self.cars = []

    def create_main_tab(self):
        # Create the main tab
        main_tab = ttk.Frame(self.tabControl)
        self.tabControl.add(main_tab, text="Main")

        # Create a label and combobox for selecting an option
        label_option = tk.Label(main_tab, text="Select an option:")
        label_option.pack()

        combo_option = ttk.Combobox(main_tab, values=["Modify Employee", "Delete Employee", "Add Employee",
                                                      "Display Car Details", "Sales Details"])
        combo_option.pack()

        # Create a button to trigger the selected option
        button_execute = tk.Button(main_tab, text="Execute", command=lambda: self.execute_option(combo_option.get()))
        button_execute.pack()

    def execute_option(self, option):
        if option == "Add Employee":
            self.create_add_employee_tab()

    def add_employee(self, firstName, lastName, gender, dateOfBirth, contactNumber, emailAddress, ID, department,
                     jobTitle, basicSalary):
        firstName = self.first_name_entry.get()
        lastName = self.last_name_entry.get()
        gender = Gender(self.gender_combobox.get())
        dateOfBirth = self.dob_entry.get()
        contactNumber = self.contact_entry.get()
        emailAddress = self.email_entry.get()
        ID = self.id_entry.get()
        department = Department(self.department_combobox.get())
        jobTitle = JobTitle(self.job_title_combobox.get())
        basicSalary = self.basic_salary_entry.get()

        # Create an Employee instance with the provided details
        employee = Employee(firstName, lastName, gender, dateOfBirth, contactNumber, emailAddress, ID, department,
                            jobTitle, basicSalary)
        # List_employee= [self.id_entry.get(),self.first_name_entry.get(),self.last_name_entry.get(),self.gender_combobox.get(),self.dob_entry.get(),self.department_combobox.get(), self.job_title_combobox.get(), self.basic_salary_entry.get(), self.contact_entry.get(),self.email_entry.get()]

        self.employees.append(employee)
        # Save the employee to a binary file using Pickle
        # Load employees from the binary file
        try:
            with open("employees_data.pkl", "rb") as f:
                self.employees = pickle.load(f)
        except FileNotFoundError:
            with open("employees_data.pkl", "wb") as f:
                pickle.dump(self.employees, f)

        self.cars.append(employee)

        # Show a success message
        tk.messagebox.showinfo("Success", "Employee added successfully.")

    def create_add_employee_tab(self):
        add_employee_window = ttk.LabelFrame(self.tabControl, text="Add Employee")
        add_employee_window.pack(padx=10, pady=10)

        # First Name
        ttk.Label(add_employee_window, text="First Name:").grid(column=0, row=0)
        self.first_name_entry = ttk.Entry(add_employee_window, width=30)
        self.first_name_entry.grid(column=1, row=0)

        # Last Name
        ttk.Label(add_employee_window, text="Last Name:").grid(column=0, row=1)
        self.last_name_entry = ttk.Entry(add_employee_window, width=30)
        self.last_name_entry.grid(column=1, row=1)

        # Gender
        ttk.Label(add_employee_window, text="Gender:").grid(column=0, row=2)
        self.gender_combobox = ttk.Combobox(add_employee_window, values=[gender.value for gender in Gender])
        self.gender_combobox.grid(column=1, row=2)

        # Date of Birth
        ttk.Label(add_employee_window, text="Date of Birth (YYYY-MM-DD):").grid(column=0, row=3)
        self.dob_entry = ttk.Entry(add_employee_window, width=30)
        self.dob_entry.grid(column=1, row=3)

        # Contact Number
        ttk.Label(add_employee_window, text="Contact Number:").grid(column=0, row=4)
        self.contact_entry = ttk.Entry(add_employee_window, width=30)
        self.contact_entry.grid(column=1, row=4)

        # Email Address
        ttk.Label(add_employee_window, text="Email Address:").grid(column=0, row=5)
        self.email_entry = ttk.Entry(add_employee_window, width=30)
        self.email_entry.grid(column=1, row=5)

        # ID
        ttk.Label(add_employee_window, text="ID:").grid(column=0, row=6)
        self.id_entry = ttk.Entry(add_employee_window, width=30)
        self.id_entry.grid(column=1, row=6)

        # Department
        ttk.Label(add_employee_window, text="Department:").grid(column=0, row=7)
        self.department_combobox = ttk.Combobox(add_employee_window,
                                                values=[department.value for department in Department])
        self.department_combobox.grid(column=1, row=7)

        # Job Title
        ttk.Label(add_employee_window, text="Job Title:").grid(column=0, row=8)
        self.job_title_combobox = ttk.Combobox(add_employee_window, values=[job_title.value for job_title in JobTitle])
        self.job_title_combobox.grid(column=1, row=8)

        # Basic Salary
        ttk.Label(add_employee_window, text="Basic Salary:").grid(column=0, row=9)
        self.basic_salary_entry = ttk.Entry(add_employee_window, width=30)
        self.basic_salary_entry.grid(column=1, row=9)

        # Add Employee Button

        # Create a frame for the button
        button_frame = tk.Frame(add_employee_window)
        button_frame.grid(columnspan=2, padx=10)

        # Create the button inside the frame
        button_add_employee = tk.Button(button_frame, text="Add Employee", command=lambda: self.add_employee(
            self.first_name_entry.get(), self.last_name_entry.get(), self.gender_combobox.get(), self.dob_entry.get(),
            self.contact_entry.get(), self.email_entry.get(), self.id_entry.get(), self.department_combobox.get(),
            self.job_title_combobox.get(), self.basic_salary_entry.get()))
        button_add_employee.pack(pady=10)

    def add_employee(self, firstName, lastName, gender, dateOfBirth, contactNumber, emailAddress, ID, department,
                     jobTitle, basicSalary):
        firstName = self.first_name_entry.get()
        lastName = self.last_name_entry.get()
        gender = Gender(self.gender_combobox.get())
        dateOfBirth = self.dob_entry.get()
        contactNumber = self.contact_entry.get()
        emailAddress = self.email_entry.get()
        ID = self.id_entry.get()
        department = Department(self.department_combobox.get())
        jobTitle = JobTitle(self.job_title_combobox.get())
        basicSalary = self.basic_salary_entry.get()

        # Create an Employee instance with the provided details
        employee = Employee(firstName, lastName, gender, dateOfBirth, contactNumber, emailAddress, ID, department,
                            jobTitle, basicSalary)
        # List_employee= [self.id_entry.get(),self.first_name_entry.get(),self.last_name_entry.get(),self.gender_combobox.get(),self.dob_entry.get(),self.department_combobox.get(), self.job_title_combobox.get(), self.basic_salary_entry.get(), self.contact_entry.get(),self.email_entry.get()]

        self.employees.append(employee)
        # Save the employee to a binary file using Pickle
        # Load employees from the binary file
        try:
            with open("employees_data.pkl", "rb") as f:
                self.employees = pickle.load(f)
        except FileNotFoundError:
            with open("employees_data.pkl", "wb") as f:
                pickle.dump(self.employees, f)

        self.cars.append(employee)

        # Show a success message
        tk.messagebox.showinfo("Success", "Employee added successfully.")


if __name__ == "__main__":
    CarSalesGUI()

# %%
import tkinter as tk
import tkinter.messagebox as messagebox
import pickle
from tkinter import ttk, Button
from datetime import date
from datetime import datetime
from enum import Enum
import os



EMPLOYEES_FILE = 'employees_data.pkl'
employees = []
class Department(Enum):
    ACCOUNTING = "Accounting"
    IT = "Information Technology"
    MANUFACTURING = "Manufacturing"
    SALES = "Sales"
    MARKETING = "Marketing"
    HR = "Human Resources"
    ADMINISTRATION = "Administration"
    FINANCE = "Finance"
    OPERATIONS = "Operations"
    CUSTOMER_SERVICE = "Customer Service"
    PROCUREMENT = "Procurement"
    QUALITY_ASSURANCE = "Quality Assurance"

class JobTitle(Enum):
    MANAGER = "Manager"
    SALES_PERSON = "Salesperson"
    RECEPTIONIST = "Receptionist"
    MECHANIC = "Mechanic"
    ACCOUNTANT = "Accountant"
    MARKETING_SPECIALIST = "Marketing Specialist"
    HR_OFFICER = "HR Officer"
    IT_SPECIALIST = "IT Specialist"
    ADMINISTRATOR = "Administrator"
    DRIVER = "Driver"

class Gender(Enum):
    MALE = 'Male'
    FEMALE = 'Female'







class Employee:
    def __init__(self, firstName, lastName, gender, dateOfBirth, contactNumber, emailAddress, ID, department, jobTitle, basicSalary):
        self._firstName = firstName
        self._lastName = lastName
        self._gender = gender
        self._dateOfBirth = datetime.strptime(dateOfBirth, "%Y-%m-%d").date()
        self._contactNumber = contactNumber
        self._emailAddress = emailAddress
        self._age = self.calculateAge()
        self._ID = ID
        self._department = department
        self._jobTitle = jobTitle
        self._basicSalary = basicSalary
        self._customers = []
        self.employees = []


    def calculateAge(self):
        today = date.today()
        age = today.year - self._dateOfBirth.year
        if today.month < self._dateOfBirth.month or (
                today.month == self._dateOfBirth.month and today.day < self._dateOfBirth.day):
            age -= 1
        return age



class CarSalesGUI:
    def __init__(self):
        self.root = tk.Tk()
        self.tabControl = ttk.Notebook(self.root)
        self.tabControl.pack(expand=1, fill="both")
        self.create_main_tab()
        self.root.mainloop()
        self.employees = []
        self.cars = []

    def create_main_tab(self):
        # Create the main tab
        main_tab = ttk.Frame(self.tabControl)
        self.tabControl.add(main_tab, text="Main")

        # Create a label and combobox for selecting an option
        label_option = tk.Label(main_tab, text="Select an option:")
        label_option.pack()

        combo_option = ttk.Combobox(main_tab, values=["Modify Employee", "Delete Employee", "Add Employee",
                                                      "Display Car Details", "Sales Details"])
        combo_option.pack()

        # Create a button to trigger the selected option
        button_execute = tk.Button(main_tab, text="Execute", command=lambda: self.execute_option(combo_option.get()))
        button_execute.pack()

    def execute_option(self, option):
        if option == "Add Employee":
            self.create_add_employee_tab()
 




    def add_employee(self, firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress, ID, department, jobTitle, basicSalary):
        firstName = self.first_name_entry.get()
        lastName = self.last_name_entry.get()
        gender = Gender(self.gender_combobox.get())
        dateOfBirth = self.dob_entry.get()
        contactNumber = self.contact_entry.get()
        emailAddress = self.email_entry.get()
        ID = self.id_entry.get()
        department = Department(self.department_combobox.get())
        jobTitle = JobTitle(self.job_title_combobox.get())
        basicSalary = self.basic_salary_entry.get()

        # Create an Employee instance with the provided details
        employee = Employee(firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress, ID, department, jobTitle, basicSalary)
        #List_employee= [self.id_entry.get(),self.first_name_entry.get(),self.last_name_entry.get(),self.gender_combobox.get(),self.dob_entry.get(),self.department_combobox.get(), self.job_title_combobox.get(), self.basic_salary_entry.get(), self.contact_entry.get(),self.email_entry.get()]

        self.employees.append(employee)
        # Save the employee to a binary file using Pickle
        # Load employees from the binary file
        try:
            with open("employees_data.pkl", "rb") as f:
                self.employees = pickle.load(f)
        except FileNotFoundError:
            with open("employees_data.pkl", "wb") as f:
                pickle.dump(self.employees, f)

        self.cars.append(employee)

        # Show a success message
        tk.messagebox.showinfo("Success", "Employee added successfully.")

    def create_add_employee_tab(self):
        add_employee_window = ttk.LabelFrame(self.tabControl, text="Add Employee")
        add_employee_window.pack(padx=10, pady=10)

        # First Name
        ttk.Label(add_employee_window, text="First Name:").grid(column=0, row=0)
        self.first_name_entry = ttk.Entry(add_employee_window, width=30)
        self.first_name_entry.grid(column=1, row=0)

        # Last Name
        ttk.Label(add_employee_window, text="Last Name:").grid(column=0, row=1)
        self.last_name_entry = ttk.Entry(add_employee_window, width=30)
        self.last_name_entry.grid(column=1, row=1)

        # Gender
        ttk.Label(add_employee_window, text="Gender:").grid(column=0, row=2)
        self.gender_combobox = ttk.Combobox(add_employee_window, values=[gender.value for gender in Gender])
        self.gender_combobox.grid(column=1, row=2)

        # Date of Birth
        ttk.Label(add_employee_window, text="Date of Birth (YYYY-MM-DD):").grid(column=0, row=3)
        self.dob_entry = ttk.Entry(add_employee_window, width=30)
        self.dob_entry.grid(column=1, row=3)

        # Contact Number
        ttk.Label(add_employee_window, text="Contact Number:").grid(column=0, row=4)
        self.contact_entry = ttk.Entry(add_employee_window, width=30)
        self.contact_entry.grid(column=1, row=4)

        # Email Address
        ttk.Label(add_employee_window, text="Email Address:").grid(column=0, row=5)
        self.email_entry = ttk.Entry(add_employee_window, width=30)
        self.email_entry.grid(column=1, row=5)

        # ID
        ttk.Label(add_employee_window, text="ID:").grid(column=0, row=6)
        self.id_entry = ttk.Entry(add_employee_window, width=30)
        self.id_entry.grid(column=1, row=6)

        # Department
        ttk.Label(add_employee_window, text="Department:").grid(column=0, row=7)
        self.department_combobox = ttk.Combobox(add_employee_window,
                                                values=[department.value for department in Department])
        self.department_combobox.grid(column=1, row=7)

        # Job Title
        ttk.Label(add_employee_window, text="Job Title:").grid(column=0, row=8)
        self.job_title_combobox = ttk.Combobox(add_employee_window, values=[job_title.value for job_title in JobTitle])
        self.job_title_combobox.grid(column=1, row=8)

        # Basic Salary
        ttk.Label(add_employee_window, text="Basic Salary:").grid(column=0, row=9)
        self.basic_salary_entry = ttk.Entry(add_employee_window, width=30)
        self.basic_salary_entry.grid(column=1, row=9)



        # Add Employee Button

        # Create a frame for the button
        button_frame = tk.Frame(add_employee_window)
        button_frame.grid(columnspan=2, padx=10)


        # Create the button inside the frame
        button_add_employee = tk.Button(button_frame, text="Add Employee", command=lambda: self.add_employee(
            self.first_name_entry.get(), self.last_name_entry.get(), self.gender_combobox.get(), self.dob_entry.get(),
            self.contact_entry.get(), self.email_entry.get(), self.id_entry.get(), self.department_combobox.get(),
            self.job_title_combobox.get(), self.basic_salary_entry.get()))
        button_add_employee.pack(pady=10)


    def add_employee(self, firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress, ID, department, jobTitle, basicSalary):
        firstName = self.first_name_entry.get()
        lastName = self.last_name_entry.get()
        gender = Gender(self.gender_combobox.get())
        dateOfBirth = self.dob_entry.get()
        contactNumber = self.contact_entry.get()
        emailAddress = self.email_entry.get()
        ID = self.id_entry.get()
        department = Department(self.department_combobox.get())
        jobTitle = JobTitle(self.job_title_combobox.get())
        basicSalary = self.basic_salary_entry.get()

        # Create an Employee instance with the provided details
        employee = Employee(firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress, ID, department, jobTitle, basicSalary)
        #List_employee= [self.id_entry.get(),self.first_name_entry.get(),self.last_name_entry.get(),self.gender_combobox.get(),self.dob_entry.get(),self.department_combobox.get(), self.job_title_combobox.get(), self.basic_salary_entry.get(), self.contact_entry.get(),self.email_entry.get()]

        self.employees.append(employee)
        # Save the employee to a binary file using Pickle
        # Load employees from the binary file
        try:
            with open("employees_data.pkl", "rb") as f:
                self.employees = pickle.load(f)
        except FileNotFoundError:
            with open("employees_data.pkl", "wb") as f:
                pickle.dump(self.employees, f)

        self.cars.append(employee)

        # Show a success message
        tk.messagebox.showinfo("Success", "Employee added successfully.")

        
if __name__ == "__main__":
    CarSalesGUI()

# %%
import tkinter as tk
import tkinter.messagebox as messagebox
import pickle
from tkinter import ttk, Button
from datetime import date
from datetime import datetime
from enum import Enum
import os



EMPLOYEES_FILE = 'employees_data.pkl'
employees = []
class Department(Enum):
    ACCOUNTING = "Accounting"
    IT = "Information Technology"
    MANUFACTURING = "Manufacturing"
    SALES = "Sales"
    MARKETING = "Marketing"
    HR = "Human Resources"
    ADMINISTRATION = "Administration"
    FINANCE = "Finance"
    OPERATIONS = "Operations"
    CUSTOMER_SERVICE = "Customer Service"
    PROCUREMENT = "Procurement"
    QUALITY_ASSURANCE = "Quality Assurance"

class JobTitle(Enum):
    MANAGER = "Manager"
    SALES_PERSON = "Salesperson"
    RECEPTIONIST = "Receptionist"
    MECHANIC = "Mechanic"
    ACCOUNTANT = "Accountant"
    MARKETING_SPECIALIST = "Marketing Specialist"
    HR_OFFICER = "HR Officer"
    IT_SPECIALIST = "IT Specialist"
    ADMINISTRATOR = "Administrator"
    DRIVER = "Driver"

class Gender(Enum):
    MALE = 'Male'
    FEMALE = 'Female'







class Employee:
    def __init__(self, firstName, lastName, gender, dateOfBirth, contactNumber, emailAddress, ID, department, jobTitle, basicSalary):
        self._firstName = firstName
        self._lastName = lastName
        self._gender = gender
        self._dateOfBirth = datetime.strptime(dateOfBirth, "%Y-%m-%d").date()
        self._contactNumber = contactNumber
        self._emailAddress = emailAddress
        self._age = self.calculateAge()
        self._ID = ID
        self._department = department
        self._jobTitle = jobTitle
        self._basicSalary = basicSalary
        self._customers = []
        self.employees = []


    def calculateAge(self):
        today = date.today()
        age = today.year - self._dateOfBirth.year
        if today.month < self._dateOfBirth.month or (
                today.month == self._dateOfBirth.month and today.day < self._dateOfBirth.day):
            age -= 1
        return age


class Car:
    def __init__(self, carID, price, carType, fuelCapacity, maxSpeed, color, mileage, is_new):
        self._carID = carID
        self._price = price
        self._carType = carType
        self._fuelCapacity = fuelCapacity
        self._maxSpeed = maxSpeed
        self._color = color
        self._mileage = mileage
        self._is_new = is_new

class CarSalesGUI:
    def __init__(self):
        self.root = tk.Tk()
        self.tabControl = ttk.Notebook(self.root)
        self.tabControl.pack(expand=1, fill="both")
        self.create_main_tab()
        self.root.mainloop()
        self.employees = []
        self.cars = []

    def create_main_tab(self):
        # Create the main tab
        main_tab = ttk.Frame(self.tabControl)
        self.tabControl.add(main_tab, text="Main")

        # Create a label and combobox for selecting an option
        label_option = tk.Label(main_tab, text="Select an option:")
        label_option.pack()

        combo_option = ttk.Combobox(main_tab, values=["Modify Employee", "Delete Employee", "Add Employee",
                                                      "Display Car Details", "Sales Details"])
        combo_option.pack()

        # Create a button to trigger the selected option
        button_execute = tk.Button(main_tab, text="Execute", command=lambda: self.execute_option(combo_option.get()))
        button_execute.pack()

    def execute_option(self, option):
        if option == "Modify Employee":
            self.create_modify_employee_tab()
        elif option == "Delete Employee":
            self.create_delete_employee_tab()
        elif option == "Add Employee":
            self.create_add_employee_tab()
        elif option == "Display Car Details":
            self.create_display_car_details_tab()
        elif option == "Sales Details":
            self.create_sales_details_tab()

    def create_modify_employee_tab(self):
        # Create the modify employee tab
        modify_employee_window = tk.Toplevel(self.root)
        modify_employee_window.title("Modify Employee")

        add_employee_window = ttk.LabelFrame(modify_employee_window, text="Add Employee")
        add_employee_window.pack(padx=10, pady=10)

        # First Name
        ttk.Label(add_employee_window, text="First Name:").grid(column=0, row=0)
        self.first_name_entry = ttk.Entry(add_employee_window, width=30)
        self.first_name_entry.grid(column=1, row=0)

        # Last Name
        ttk.Label(add_employee_window, text="Last Name:").grid(column=0, row=1)
        self.last_name_entry = ttk.Entry(add_employee_window, width=30)
        self.last_name_entry.grid(column=1, row=1)

        # Gender
        ttk.Label(add_employee_window, text="Gender:").grid(column=0, row=2)
        self.gender_combobox = ttk.Combobox(add_employee_window, values=[gender.value for gender in Gender])
        self.gender_combobox.grid(column=1, row=2)

        # Date of Birth
        ttk.Label(add_employee_window, text="Date of Birth (YYYY-MM-DD):").grid(column=0, row=3)
        self.dob_entry = ttk.Entry(add_employee_window, width=30)
        self.dob_entry.grid(column=1, row=3)

        # Contact Number
        ttk.Label(add_employee_window, text="Contact Number:").grid(column=0, row=4)
        self.contact_entry = ttk.Entry(add_employee_window, width=30)
        self.contact_entry.grid(column=1, row=4)

        # Email Address
        ttk.Label(add_employee_window, text="Email Address:").grid(column=0, row=5)
        self.email_entry = ttk.Entry(add_employee_window, width=30)
        self.email_entry.grid(column=1, row=5)

        # ID
        ttk.Label(add_employee_window, text="ID:").grid(column=0, row=6)
        self.id_entry = ttk.Entry(add_employee_window, width=30)
        self.id_entry.grid(column=1, row=6)

        # Department
        ttk.Label(add_employee_window, text="Department:").grid(column=0, row=7)
        self.department_combobox = ttk.Combobox(add_employee_window,
                                                values=[department.value for department in Department])
        self.department_combobox.grid(column=1, row=7)

        # Job Title
        ttk.Label(add_employee_window, text="Job Title:").grid(column=0, row=8)
        self.job_title_combobox = ttk.Combobox(add_employee_window, values=[job_title.value for job_title in JobTitle])
        self.job_title_combobox.grid(column=1, row=8)

        # Basic Salary
        ttk.Label(add_employee_window, text="Basic Salary:").grid(column=0, row=9)
        self.basic_salary_entry = ttk.Entry(add_employee_window, width=30)
        self.basic_salary_entry.grid(column=1, row=9)

        List_employee= [self.id_entry.get(),self.first_name_entry.get(),self.last_name_entry.get(),self.gender_combobox.get(),self.dob_entry.get(),self.department_combobox.get(), self.job_title_combobox.get(), self.basic_salary_entry.get(), self.contact_entry.get(),self.email_entry.get()]
        self.employee.append(List_employee)


        # Create a button to modify the employee
        button_modify_employee = tk.Button(modify_employee_window, text="Modify Employee",
                                           command=lambda: self.modify_employee(self.id_entry.get(),
                                                                                self.first_name_entry.get(),
                                                                                self.last_name_entry.get(),
                                                                                self.gender_combobox.get(),
                                                                                self.dob_entry.get(),
                                                                                self.department_combobox.get(),
                                                                                self.job_title_combobox.get(),
                                                                                self.basic_salary_entry.get(),
                                                                                self.contact_entry.get(),
                                                                                self.email_entry.get()
        ))
        button_modify_employee.pack()

    def create_delete_employee_tab(self):

        delete_employee_window = ttk.LabelFrame(self.tabControl, text="Delete Employee")
        delete_employee_window.pack(padx=10, pady=10)

        # Employee ID
        ttk.Label(delete_employee_window, text="Employee ID:").grid(column=0, row=0)
        self.employee_id_entry = ttk.Entry(delete_employee_window, width=30)
        self.employee_id_entry.grid(column=1, row=0)

        # Delete Employee Button
        delete_button = tk.Button(delete_employee_window, text="Delete Employee", command=self.delete_employee)
        delete_button.grid(columnspan=2, pady=10)

    def create_add_employee_tab(self):
        add_employee_window = ttk.LabelFrame(self.tabControl, text="Add Employee")
        add_employee_window.pack(padx=10, pady=10)

        # First Name
        ttk.Label(add_employee_window, text="First Name:").grid(column=0, row=0)
        self.first_name_entry = ttk.Entry(add_employee_window, width=30)
        self.first_name_entry.grid(column=1, row=0)

        # Last Name
        ttk.Label(add_employee_window, text="Last Name:").grid(column=0, row=1)
        self.last_name_entry = ttk.Entry(add_employee_window, width=30)
        self.last_name_entry.grid(column=1, row=1)

        # Gender
        ttk.Label(add_employee_window, text="Gender:").grid(column=0, row=2)
        self.gender_combobox = ttk.Combobox(add_employee_window, values=[gender.value for gender in Gender])
        self.gender_combobox.grid(column=1, row=2)

        # Date of Birth
        ttk.Label(add_employee_window, text="Date of Birth (YYYY-MM-DD):").grid(column=0, row=3)
        self.dob_entry = ttk.Entry(add_employee_window, width=30)
        self.dob_entry.grid(column=1, row=3)

        # Contact Number
        ttk.Label(add_employee_window, text="Contact Number:").grid(column=0, row=4)
        self.contact_entry = ttk.Entry(add_employee_window, width=30)
        self.contact_entry.grid(column=1, row=4)

        # Email Address
        ttk.Label(add_employee_window, text="Email Address:").grid(column=0, row=5)
        self.email_entry = ttk.Entry(add_employee_window, width=30)
        self.email_entry.grid(column=1, row=5)

        # ID
        ttk.Label(add_employee_window, text="ID:").grid(column=0, row=6)
        self.id_entry = ttk.Entry(add_employee_window, width=30)
        self.id_entry.grid(column=1, row=6)

        # Department
        ttk.Label(add_employee_window, text="Department:").grid(column=0, row=7)
        self.department_combobox = ttk.Combobox(add_employee_window,
                                                values=[department.value for department in Department])
        self.department_combobox.grid(column=1, row=7)

        # Job Title
        ttk.Label(add_employee_window, text="Job Title:").grid(column=0, row=8)
        self.job_title_combobox = ttk.Combobox(add_employee_window, values=[job_title.value for job_title in JobTitle])
        self.job_title_combobox.grid(column=1, row=8)

        # Basic Salary
        ttk.Label(add_employee_window, text="Basic Salary:").grid(column=0, row=9)
        self.basic_salary_entry = ttk.Entry(add_employee_window, width=30)
        self.basic_salary_entry.grid(column=1, row=9)



        # Add Employee Button

        # Create a frame for the button
        button_frame = tk.Frame(add_employee_window)
        button_frame.grid(columnspan=2, padx=10)


        # Create the button inside the frame
        button_add_employee = tk.Button(button_frame, text="Add Employee", command=lambda: self.add_employee(
            self.first_name_entry.get(), self.last_name_entry.get(), self.gender_combobox.get(), self.dob_entry.get(),
            self.contact_entry.get(), self.email_entry.get(), self.id_entry.get(), self.department_combobox.get(),
            self.job_title_combobox.get(), self.basic_salary_entry.get()))
        button_add_employee.pack(pady=10)




    def create_display_car_details_tab(self):
        # Create the display car details tab
        display_car_details_window = tk.Toplevel(self.root)
        display_car_details_window.title("Display Car Details")


        # Create a label and entry field for the car ID to display
        label_id = tk.Label(display_car_details_window, text="ID Number:")
        label_id.pack()
        entry_id = tk.Entry(display_car_details_window)
        entry_id.pack()

        # Create a button to display the car details
        button_display_car_details = tk.Button(display_car_details_window, text="Display Car Details",
                                               command=lambda: self.display_car_details(entry_id.get()))
        button_display_car_details.pack()
    def create_sales_details_tab(self):
        # Create the sales details tab
        sales_details_window = tk.Toplevel(self.root)
        sales_details_window.title("Sales Details")

        # Load the employees from the binary file
        employees = self.load_employees()

        # Find the employee with the provided ID number
        for employee in employees:
            if employee.id_number == id_number:
                # Show the sales details of the employee
                sales_details = ""
                for sale in employee.sales:
                    sales_details += f"Car Sold: {sale.car_name}\nSale Price: {sale.sale_price}\n\n"

                tk.messagebox.showinfo("Sales Details", sales_details)
                return


    def add_employee(self, firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress, ID, department, jobTitle, basicSalary):
        firstName = self.first_name_entry.get()
        lastName = self.last_name_entry.get()
        gender = Gender(self.gender_combobox.get())
        dateOfBirth = self.dob_entry.get()
        contactNumber = self.contact_entry.get()
        emailAddress = self.email_entry.get()
        ID = self.id_entry.get()
        department = Department(self.department_combobox.get())
        jobTitle = JobTitle(self.job_title_combobox.get())
        basicSalary = self.basic_salary_entry.get()

        # Create an Employee instance with the provided details
        employee = Employee(firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress, ID, department, jobTitle, basicSalary)
        #List_employee= [self.id_entry.get(),self.first_name_entry.get(),self.last_name_entry.get(),self.gender_combobox.get(),self.dob_entry.get(),self.department_combobox.get(), self.job_title_combobox.get(), self.basic_salary_entry.get(), self.contact_entry.get(),self.email_entry.get()]

        self.employees.append(employee)
        # Save the employee to a binary file using Pickle
        # Load employees from the binary file
        try:
            with open("employees_data.pkl", "rb") as f:
                self.employees = pickle.load(f)
        except FileNotFoundError:
            with open("employees_data.pkl", "wb") as f:
                pickle.dump(self.employees, f)

        self.cars.append(employee)

        # Show a success message
        tk.messagebox.showinfo("Success", "Employee added successfully.")

    def delete_employee(self):
        # Get the current working directory
        current_dir = os.getcwd()

        # Construct the file path relative to the current directory
        file_path = os.path.join(current_dir, 'employees.txt')

        # Open the file
        with open(file_path, 'r') as file:
            lines = file.readlines()

        # Find the employee with the given ID
        for i, line in enumerate(lines):
            if line.strip() == employee_id:
                # Remove the employee ID from the list
                del lines[i:i + 3]  # Assuming each employee record spans three lines

                # Write the updated employee data back to the file
                with open('employees.txt', 'w') as file:
                    file.writelines(lines)

                print("Employee deleted successfully.")
                return

        # Employee ID not found
        print("Employee not found.")

    def modify_employee(self):
        # Get the values from the entry fields
        first_name = self.first_name_entry.get()
        last_name = self.last_name_entry.get()
        gender = Gender(self.gender_combobox.get())
        date_of_birth = self.dob_entry.get()
        contact_number = self.contact_entry.get()
        email_address = self.email_entry.get()
        id_number = self.id_entry.get()
        department = Department(self.department_combobox.get())
        job_title = JobTitle(self.job_title_combobox.get())
        basic_salary = self.basic_salary_entry.get()

        # Perform the modification logic
        # Assuming you have a list of employees, you can iterate over the list and find the employee with the matching ID
        for employee in self.employees:
            if employee.id == id_number:
                # Modify the employee attributes
                employee.first_name = first_name
                employee.last_name = last_name
                employee.gender = gender
                employee.date_of_birth = date_of_birth
                employee.contact_number = contact_number
                employee.email_address = email_address
                employee.department = department
                employee.job_title = job_title
                employee.basic_salary = basic_salary

                try:
                    with open("employees_data.pkl", "rb") as f:
                        self.employees = pickle.load(f)
                except FileNotFoundError:
                    with open("employees_data.pkl", "wb") as f:
                        pickle.dump(self.employees, f)

                self.cars.append(employee)

        # Clear the entry fields
        self.first_name_entry.delete(0, tk.END)
        self.last_name_entry.delete(0, tk.END)
        self.gender_combobox.set('')
        self.dob_entry.delete(0, tk.END)
        self.contact_entry.delete(0, tk.END)
        self.email_entry.delete(0, tk.END)
        self.id_entry.delete(0, tk.END)
        self.department_combobox.set('')
        self.job_title_combobox.set('')
        self.basic_salary_entry.delete(0, tk.END)

        # Show a message or perform any other desired actions
        messagebox.showinfo("Modification Successful", "Employee modified successfully.")

    def clear_entry_fields(self):
        # Clear all the entry fields
        entry_first_name.delete(0, tk.END)
        entry_last_name.delete(0, tk.END)
        entry_gender.delete(0, tk.END)
        entry_date_of_birth.delete(0, tk.END)
        entry_contact_number.delete(0, tk.END)
        entry_email_address.delete(0, tk.END)
        entry_id.delete(0, tk.END)
        entry_department.delete(0, tk.END)
        entry_job_title.delete(0, tk.END)
        entry_basic_salary.delete(0, tk.END)

    def get_data_file_path(self, file_name):
        script_dir = os.path.dirname(os.path.abspath(__file__))
        data_dir = os.path.join(script_dir, 'data')
        os.makedirs(data_dir, exist_ok=True)
        file_path = os.path.join(data_dir, file_name)
        return file_path

    def load_employees(self):
        file_path = self.get_data_file_path('employees_data.pkl')
        try:
            with open(file_path, 'rb') as file:
                employees = pickle.load(file)
        except FileNotFoundError:
            employees = []
        return employees

    def save_data(self):
        file_path = self.get_data_file_path('employees_data.pkl')
        with open(file_path, 'wb') as file:
            pickle.dump(self.employees, file)

    def load_cars(self):
        # Load cars from the binary file
        try:
            with open("cars.pkl", "rb") as file:
                cars = []
                while True:
                    try:
                        car = pickle.load(file)
                        cars.append(car)
                    except EOFError:
                        break
                return cars
        except FileNotFoundError:
            return []

    def save_cars(self, cars):
        # Save cars to the binary file
        with open("cars.pkl", "wb") as file:
            for car in cars:
                pickle.dump(car, file)


if __name__ == "__main__":
    CarSalesGUI()

# %%
import tkinter as tk
import tkinter.messagebox as messagebox
import pickle
from tkinter import ttk, Button
from datetime import date
from datetime import datetime
from enum import Enum
import os




class Department(Enum):
    ACCOUNTING = "Accounting"
    IT = "Information Technology"
    MANUFACTURING = "Manufacturing"
    SALES = "Sales"
    MARKETING = "Marketing"
    HR = "Human Resources"
    ADMINISTRATION = "Administration"
    FINANCE = "Finance"
    OPERATIONS = "Operations"
    CUSTOMER_SERVICE = "Customer Service"
    PROCUREMENT = "Procurement"
    QUALITY_ASSURANCE = "Quality Assurance"

class JobTitle(Enum):
    MANAGER = "Manager"
    SALES_PERSON = "Salesperson"
    RECEPTIONIST = "Receptionist"
    MECHANIC = "Mechanic"
    ACCOUNTANT = "Accountant"
    MARKETING_SPECIALIST = "Marketing Specialist"
    HR_OFFICER = "HR Officer"
    IT_SPECIALIST = "IT Specialist"
    ADMINISTRATOR = "Administrator"
    DRIVER = "Driver"

class Gender(Enum):
    MALE = 'Male'
    FEMALE = 'Female'







class Employee:
    def __init__(self, firstName, lastName, gender, dateOfBirth, contactNumber, emailAddress, ID, department, jobTitle, basicSalary):
        self._firstName = firstName
        self._lastName = lastName
        self._gender = gender
        self._dateOfBirth = datetime.strptime(dateOfBirth, "%Y-%m-%d").date()
        self._contactNumber = contactNumber
        self._emailAddress = emailAddress
        self._age = self.calculateAge()
        self._ID = ID
        self._department = department
        self._jobTitle = jobTitle
        self._basicSalary = basicSalary
        self._customers = []
        self.employees = []


    def calculateAge(self):
        today = date.today()
        age = today.year - self._dateOfBirth.year
        if today.month < self._dateOfBirth.month or (
                today.month == self._dateOfBirth.month and today.day < self._dateOfBirth.day):
            age -= 1
        return age


class Car:
    def __init__(self, carID, price, carType, fuelCapacity, maxSpeed, color, mileage, is_new):
        self._carID = carID
        self._price = price
        self._carType = carType
        self._fuelCapacity = fuelCapacity
        self._maxSpeed = maxSpeed
        self._color = color
        self._mileage = mileage
        self._is_new = is_new

class CarSalesGUI:
    def __init__(self):
        self.root = tk.Tk()
        self.tabControl = ttk.Notebook(self.root)
        self.tabControl.pack(expand=1, fill="both")
        self.create_main_tab()
        self.root.mainloop()
        self.employees = []
        self.cars = []

        try:
            with open("cars_data.pkl", "rb") as f:
                self.cars = pickle.load(f)
        except FileNotFoundError:
            with open("cars_data.pkl", "wb") as f:
                pickle.dump(self.cars, f)

        try:
            with open("employees_data.pkl", "rb") as f:
                self.employees = pickle.load(f)
        except FileNotFoundError:
            with open("employees_data.pkl", "wb") as f:
                pickle.dump(self.employees, f)

    def create_main_tab(self):
        # Create the main tab
        main_tab = ttk.Frame(self.tabControl)
        self.tabControl.add(main_tab, text="Main")

        # Create a label and combobox for selecting an option
        label_option = tk.Label(main_tab, text="Select an option:")
        label_option.pack()

        combo_option = ttk.Combobox(main_tab, values=["Modify Employee", "Delete Employee", "Add Employee",
                                                      "Display Car Details", "Sales Details"])
        combo_option.pack()

        # Create a button to trigger the selected option
        button_execute = tk.Button(main_tab, text="Execute", command=lambda: self.execute_option(combo_option.get()))
        button_execute.pack()

    def execute_option(self, option):
        if option == "Modify Employee":
            self.create_modify_employee_tab()
        elif option == "Delete Employee":
            self.create_delete_employee_tab()
        elif option == "Add Employee":
            self.create_add_employee_tab()
        elif option == "Display Car Details":
            self.create_display_car_details_tab()
        elif option == "Sales Details":
            self.create_sales_details_tab()

    def create_modify_employee_tab(self):
        # Create the modify employee tab
        modify_employee_window = tk.Toplevel(self.root)
        modify_employee_window.title("Modify Employee")

        add_employee_window = ttk.LabelFrame(modify_employee_window, text="Add Employee")
        add_employee_window.pack(padx=10, pady=10)

        # First Name
        ttk.Label(add_employee_window, text="First Name:").grid(column=0, row=0)
        self.first_name_entry = ttk.Entry(add_employee_window, width=30)
        self.first_name_entry.grid(column=1, row=0)

        # Last Name
        ttk.Label(add_employee_window, text="Last Name:").grid(column=0, row=1)
        self.last_name_entry = ttk.Entry(add_employee_window, width=30)
        self.last_name_entry.grid(column=1, row=1)

        # Gender
        ttk.Label(add_employee_window, text="Gender:").grid(column=0, row=2)
        self.gender_combobox = ttk.Combobox(add_employee_window, values=[gender.value for gender in Gender])
        self.gender_combobox.grid(column=1, row=2)

        # Date of Birth
        ttk.Label(add_employee_window, text="Date of Birth (YYYY-MM-DD):").grid(column=0, row=3)
        self.dob_entry = ttk.Entry(add_employee_window, width=30)
        self.dob_entry.grid(column=1, row=3)

        # Contact Number
        ttk.Label(add_employee_window, text="Contact Number:").grid(column=0, row=4)
        self.contact_entry = ttk.Entry(add_employee_window, width=30)
        self.contact_entry.grid(column=1, row=4)

        # Email Address
        ttk.Label(add_employee_window, text="Email Address:").grid(column=0, row=5)
        self.email_entry = ttk.Entry(add_employee_window, width=30)
        self.email_entry.grid(column=1, row=5)

        # ID
        ttk.Label(add_employee_window, text="ID:").grid(column=0, row=6)
        self.id_entry = ttk.Entry(add_employee_window, width=30)
        self.id_entry.grid(column=1, row=6)

        # Department
        ttk.Label(add_employee_window, text="Department:").grid(column=0, row=7)
        self.department_combobox = ttk.Combobox(add_employee_window,
                                                values=[department.value for department in Department])
        self.department_combobox.grid(column=1, row=7)

        # Job Title
        ttk.Label(add_employee_window, text="Job Title:").grid(column=0, row=8)
        self.job_title_combobox = ttk.Combobox(add_employee_window, values=[job_title.value for job_title in JobTitle])
        self.job_title_combobox.grid(column=1, row=8)

        # Basic Salary
        ttk.Label(add_employee_window, text="Basic Salary:").grid(column=0, row=9)
        self.basic_salary_entry = ttk.Entry(add_employee_window, width=30)
        self.basic_salary_entry.grid(column=1, row=9)

        # Create a button to modify the employee
        button_modify_employee = tk.Button(modify_employee_window, text="Modify Employee",
                                           command=lambda: self.modify_employee(self.id_entry.get(),
                                                                                self.first_name_entry.get(),
                                                                                self.department_combobox.get(),
                                                                                self.job_title_combobox.get(),
                                                                                self.basic_salary_entry.get()))
        button_modify_employee.pack()

    def create_delete_employee_tab(self):

        delete_employee_window = ttk.LabelFrame(self.tabControl, text="Delete Employee")
        delete_employee_window.pack(padx=10, pady=10)

        # Employee ID
        ttk.Label(delete_employee_window, text="Employee ID:").grid(column=0, row=0)
        self.employee_id_entry = ttk.Entry(delete_employee_window, width=30)
        self.employee_id_entry.grid(column=1, row=0)

        # Delete Employee Button
        delete_button = tk.Button(delete_employee_window, text="Delete Employee", command=self.delete_employee)
        delete_button.grid(columnspan=2, pady=10)

    def create_add_employee_tab(self):
        add_employee_window = ttk.LabelFrame(self.tabControl, text="Add Employee")
        add_employee_window.pack(padx=10, pady=10)

        # First Name
        ttk.Label(add_employee_window, text="First Name:").grid(column=0, row=0)
        self.first_name_entry = ttk.Entry(add_employee_window, width=30)
        self.first_name_entry.grid(column=1, row=0)

        # Last Name
        ttk.Label(add_employee_window, text="Last Name:").grid(column=0, row=1)
        self.last_name_entry = ttk.Entry(add_employee_window, width=30)
        self.last_name_entry.grid(column=1, row=1)

        # Gender
        ttk.Label(add_employee_window, text="Gender:").grid(column=0, row=2)
        self.gender_combobox = ttk.Combobox(add_employee_window, values=[gender.value for gender in Gender])
        self.gender_combobox.grid(column=1, row=2)

        # Date of Birth
        ttk.Label(add_employee_window, text="Date of Birth (YYYY-MM-DD):").grid(column=0, row=3)
        self.dob_entry = ttk.Entry(add_employee_window, width=30)
        self.dob_entry.grid(column=1, row=3)

        # Contact Number
        ttk.Label(add_employee_window, text="Contact Number:").grid(column=0, row=4)
        self.contact_entry = ttk.Entry(add_employee_window, width=30)
        self.contact_entry.grid(column=1, row=4)

        # Email Address
        ttk.Label(add_employee_window, text="Email Address:").grid(column=0, row=5)
        self.email_entry = ttk.Entry(add_employee_window, width=30)
        self.email_entry.grid(column=1, row=5)

        # ID
        ttk.Label(add_employee_window, text="ID:").grid(column=0, row=6)
        self.id_entry = ttk.Entry(add_employee_window, width=30)
        self.id_entry.grid(column=1, row=6)

        # Department
        ttk.Label(add_employee_window, text="Department:").grid(column=0, row=7)
        self.department_combobox = ttk.Combobox(add_employee_window,
                                                values=[department.value for department in Department])
        self.department_combobox.grid(column=1, row=7)

        # Job Title
        ttk.Label(add_employee_window, text="Job Title:").grid(column=0, row=8)
        self.job_title_combobox = ttk.Combobox(add_employee_window, values=[job_title.value for job_title in JobTitle])
        self.job_title_combobox.grid(column=1, row=8)

        # Basic Salary
        ttk.Label(add_employee_window, text="Basic Salary:").grid(column=0, row=9)
        self.basic_salary_entry = ttk.Entry(add_employee_window, width=30)
        self.basic_salary_entry.grid(column=1, row=9)

        # Add Employee Button

        # Create a frame for the button
        button_frame = tk.Frame(add_employee_window)
        button_frame.grid(columnspan=2, padx=10)


        # Create the button inside the frame
        button_add_employee = tk.Button(button_frame, text="Add Employee", command=lambda: self.add_employee(
            self.first_name_entry.get(), self.last_name_entry.get(), self.gender_combobox.get(), self.dob_entry.get(),
            self.contact_entry.get(), self.email_entry.get(), self.id_entry.get(), self.department_combobox.get(),
            self.job_title_combobox.get(), self.basic_salary_entry.get()))
        button_add_employee.pack(pady=10)




    def create_display_car_details_tab(self):
        # Create the display car details tab
        display_car_details_window = tk.Toplevel(self.root)
        display_car_details_window.title("Display Car Details")


        # Create a label and entry field for the car ID to display
        label_id = tk.Label(display_car_details_window, text="ID Number:")
        label_id.pack()
        entry_id = tk.Entry(display_car_details_window)
        entry_id.pack()

        # Create a button to display the car details
        button_display_car_details = tk.Button(display_car_details_window, text="Display Car Details",
                                               command=lambda: self.display_car_details(entry_id.get()))
        button_display_car_details.pack()
    def create_sales_details_tab(self):
        # Create the sales details tab
        sales_details_window = tk.Toplevel(self.root)
        sales_details_window.title("Sales Details")

        # Load the employees from the binary file
        employees = self.load_employees()

        # Find the employee with the provided ID number
        for employee in employees:
            if employee.id_number == id_number:
                # Show the sales details of the employee
                sales_details = ""
                for sale in employee.sales:
                    sales_details += f"Car Sold: {sale.car_name}\nSale Price: {sale.sale_price}\n\n"

                tk.messagebox.showinfo("Sales Details", sales_details)
                return


    def add_employee(self, firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress, ID, department, jobTitle, basicSalary):
        firstName = self.first_name_entry.get()
        lastName = self.last_name_entry.get()
        gender = Gender(self.gender_combobox.get())
        dateOfBirth = self.dob_entry.get()
        contactNumber = self.contact_entry.get()
        emailAddress = self.email_entry.get()
        ID = self.id_entry.get()
        department = Department(self.department_combobox.get())
        jobTitle = JobTitle(self.job_title_combobox.get())
        basicSalary = self.basic_salary_entry.get()

        # Create an Employee instance with the provided details
        employee = Employee(firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress, ID, department, jobTitle, basicSalary)

        # Save the employee to a binary file using Pickle
        # Load employees from the binary file
        try:
            with open("employees_data.pkl", "rb") as f:
                self.employees = pickle.load(f)
        except FileNotFoundError:
            with open("employees_data.pkl", "wb") as f:
                pickle.dump(self.employees, f)

        self.cars.append(employee)

        # Show a success message
        tk.messagebox.showinfo("Success", "Employee added successfully.")

    def delete_employee(self):
        # Get the current working directory
        current_dir = os.getcwd()

        # Construct the file path relative to the current directory
        file_path = os.path.join(current_dir, 'employees.txt')

        # Open the file
        with open(file_path, 'r') as file:
            lines = file.readlines()

        # Find the employee with the given ID
        for i, line in enumerate(lines):
            if line.strip() == employee_id:
                # Remove the employee ID from the list
                del lines[i:i + 3]  # Assuming each employee record spans three lines

                # Write the updated employee data back to the file
                with open('employees.txt', 'w') as file:
                    file.writelines(lines)

                print("Employee deleted successfully.")
                return

        # Employee ID not found
        print("Employee not found.")

    def modify_employee(self):
        # Get the values from the entry fields
        first_name = self.first_name_entry.get()
        last_name = self.last_name_entry.get()
        gender = Gender(self.gender_combobox.get())
        date_of_birth = self.dob_entry.get()
        contact_number = self.contact_entry.get()
        email_address = self.email_entry.get()
        id_number = self.id_entry.get()
        department = Department(self.department_combobox.get())
        job_title = JobTitle(self.job_title_combobox.get())
        basic_salary = self.basic_salary_entry.get()

        # Perform the modification logic
        # Assuming you have a list of employees, you can iterate over the list and find the employee with the matching ID
        for employee in self.employees:
            if employee.id == id_number:
                # Modify the employee attributes
                employee.first_name = first_name
                employee.last_name = last_name
                employee.gender = gender
                employee.date_of_birth = date_of_birth
                employee.contact_number = contact_number
                employee.email_address = email_address
                employee.department = department
                employee.job_title = job_title
                employee.basic_salary = basic_salary

                try:
                    with open("employees_data.pkl", "rb") as f:
                        self.employees = pickle.load(f)
                except FileNotFoundError:
                    with open("employees_data.pkl", "wb") as f:
                        pickle.dump(self.employees, f)

                self.cars.append(employee)

        # Clear the entry fields
        self.first_name_entry.delete(0, tk.END)
        self.last_name_entry.delete(0, tk.END)
        self.gender_combobox.set('')
        self.dob_entry.delete(0, tk.END)
        self.contact_entry.delete(0, tk.END)
        self.email_entry.delete(0, tk.END)
        self.id_entry.delete(0, tk.END)
        self.department_combobox.set('')
        self.job_title_combobox.set('')
        self.basic_salary_entry.delete(0, tk.END)

        # Show a message or perform any other desired actions
        messagebox.showinfo("Modification Successful", "Employee modified successfully.")

    def clear_entry_fields(self):
        # Clear all the entry fields
        entry_first_name.delete(0, tk.END)
        entry_last_name.delete(0, tk.END)
        entry_gender.delete(0, tk.END)
        entry_date_of_birth.delete(0, tk.END)
        entry_contact_number.delete(0, tk.END)
        entry_email_address.delete(0, tk.END)
        entry_id.delete(0, tk.END)
        entry_department.delete(0, tk.END)
        entry_job_title.delete(0, tk.END)
        entry_basic_salary.delete(0, tk.END)

    def load_employees(self):
        # Load employees from the binary file
        try:
            with open("employees.pkl", "rb") as file:
                employees = []
                while True:
                    try:
                        employee = pickle.load(file)
                        employees.append(employee)
                    except EOFError:
                        break
                return employees
        except FileNotFoundError:
            return []

    def save_employees(self, employees):
        # Save employees to the binary file
        with open("employees.pkl", "wb") as file:
            for employee in employees:
                pickle.dump(employee, file)

    def load_cars(self):
        # Load cars from the binary file
        try:
            with open("cars.pkl", "rb") as file:
                cars = []
                while True:
                    try:
                        car = pickle.load(file)
                        cars.append(car)
                    except EOFError:
                        break
                return cars
        except FileNotFoundError:
            return []

    def save_cars(self, cars):
        # Save cars to the binary file
        with open("cars.pkl", "wb") as file:
            for car in cars:
                pickle.dump(car, file)


if __name__ == "__main__":
    CarSalesGUI()

# %%
#best version without modifying in the file ::

import tkinter as tk
import tkinter.messagebox as messagebox
import pickle
from tkinter import ttk, Button
from datetime import date
from datetime import datetime
from enum import Enum
import os




class Department(Enum):
    ACCOUNTING = "Accounting"
    IT = "Information Technology"
    MANUFACTURING = "Manufacturing"
    SALES = "Sales"
    MARKETING = "Marketing"
    HR = "Human Resources"
    ADMINISTRATION = "Administration"
    FINANCE = "Finance"
    OPERATIONS = "Operations"
    CUSTOMER_SERVICE = "Customer Service"
    PROCUREMENT = "Procurement"
    QUALITY_ASSURANCE = "Quality Assurance"

class JobTitle(Enum):
    MANAGER = "Manager"
    SALES_PERSON = "Salesperson"
    RECEPTIONIST = "Receptionist"
    MECHANIC = "Mechanic"
    ACCOUNTANT = "Accountant"
    MARKETING_SPECIALIST = "Marketing Specialist"
    HR_OFFICER = "HR Officer"
    IT_SPECIALIST = "IT Specialist"
    ADMINISTRATOR = "Administrator"
    DRIVER = "Driver"

class Gender(Enum):
    MALE = 'Male'
    FEMALE = 'Female'







class Employee:
    def __init__(self, firstName, lastName, gender, dateOfBirth, contactNumber, emailAddress, ID, department, jobTitle, basicSalary):
        self._firstName = firstName
        self._lastName = lastName
        self._gender = gender
        self._dateOfBirth = datetime.strptime(dateOfBirth, "%Y-%m-%d").date()
        self._contactNumber = contactNumber
        self._emailAddress = emailAddress
        self._age = self.calculateAge()
        self._ID = ID
        self._department = department
        self._jobTitle = jobTitle
        self._basicSalary = basicSalary
        self._customers = []
        self.employees = []


    def calculateAge(self):
        today = date.today()
        age = today.year - self._dateOfBirth.year
        if today.month < self._dateOfBirth.month or (
                today.month == self._dateOfBirth.month and today.day < self._dateOfBirth.day):
            age -= 1
        return age


class Car:
    def __init__(self, carID, price, carType, fuelCapacity, maxSpeed, color, mileage, is_new):
        self._carID = carID
        self._price = price
        self._carType = carType
        self._fuelCapacity = fuelCapacity
        self._maxSpeed = maxSpeed
        self._color = color
        self._mileage = mileage
        self._is_new = is_new

class CarSalesGUI:
    def __init__(self):
        self.root = tk.Tk()
        self.tabControl = ttk.Notebook(self.root)
        self.tabControl.pack(expand=1, fill="both")
        self.create_main_tab()
        self.root.mainloop()

    def create_main_tab(self):
        # Create the main tab
        main_tab = ttk.Frame(self.tabControl)
        self.tabControl.add(main_tab, text="Main")

        # Create a label and combobox for selecting an option
        label_option = tk.Label(main_tab, text="Select an option:")
        label_option.pack()

        combo_option = ttk.Combobox(main_tab, values=["Modify Employee", "Delete Employee", "Add Employee",
                                                      "Display Car Details", "Sales Details"])
        combo_option.pack()

        # Create a button to trigger the selected option
        button_execute = tk.Button(main_tab, text="Execute", command=lambda: self.execute_option(combo_option.get()))
        button_execute.pack()

    def execute_option(self, option):
        if option == "Modify Employee":
            self.create_modify_employee_tab()
        elif option == "Delete Employee":
            self.create_delete_employee_tab()
        elif option == "Add Employee":
            self.create_add_employee_tab()
        elif option == "Display Car Details":
            self.create_display_car_details_tab()
        elif option == "Sales Details":
            self.create_sales_details_tab()

    def create_modify_employee_tab(self):
        # Create the modify employee tab
        modify_employee_window = tk.Toplevel(self.root)
        modify_employee_window.title("Modify Employee")

        add_employee_window = ttk.LabelFrame(modify_employee_window, text="Add Employee")
        add_employee_window.pack(padx=10, pady=10)

        # First Name
        ttk.Label(add_employee_window, text="First Name:").grid(column=0, row=0)
        self.first_name_entry = ttk.Entry(add_employee_window, width=30)
        self.first_name_entry.grid(column=1, row=0)

        # Last Name
        ttk.Label(add_employee_window, text="Last Name:").grid(column=0, row=1)
        self.last_name_entry = ttk.Entry(add_employee_window, width=30)
        self.last_name_entry.grid(column=1, row=1)

        # Gender
        ttk.Label(add_employee_window, text="Gender:").grid(column=0, row=2)
        self.gender_combobox = ttk.Combobox(add_employee_window, values=[gender.value for gender in Gender])
        self.gender_combobox.grid(column=1, row=2)

        # Date of Birth
        ttk.Label(add_employee_window, text="Date of Birth (YYYY-MM-DD):").grid(column=0, row=3)
        self.dob_entry = ttk.Entry(add_employee_window, width=30)
        self.dob_entry.grid(column=1, row=3)

        # Contact Number
        ttk.Label(add_employee_window, text="Contact Number:").grid(column=0, row=4)
        self.contact_entry = ttk.Entry(add_employee_window, width=30)
        self.contact_entry.grid(column=1, row=4)

        # Email Address
        ttk.Label(add_employee_window, text="Email Address:").grid(column=0, row=5)
        self.email_entry = ttk.Entry(add_employee_window, width=30)
        self.email_entry.grid(column=1, row=5)

        # ID
        ttk.Label(add_employee_window, text="ID:").grid(column=0, row=6)
        self.id_entry = ttk.Entry(add_employee_window, width=30)
        self.id_entry.grid(column=1, row=6)

        # Department
        ttk.Label(add_employee_window, text="Department:").grid(column=0, row=7)
        self.department_combobox = ttk.Combobox(add_employee_window,
                                                values=[department.value for department in Department])
        self.department_combobox.grid(column=1, row=7)

        # Job Title
        ttk.Label(add_employee_window, text="Job Title:").grid(column=0, row=8)
        self.job_title_combobox = ttk.Combobox(add_employee_window, values=[job_title.value for job_title in JobTitle])
        self.job_title_combobox.grid(column=1, row=8)

        # Basic Salary
        ttk.Label(add_employee_window, text="Basic Salary:").grid(column=0, row=9)
        self.basic_salary_entry = ttk.Entry(add_employee_window, width=30)
        self.basic_salary_entry.grid(column=1, row=9)

        # Create a button to modify the employee
        button_modify_employee = tk.Button(modify_employee_window, text="Modify Employee",
                                           command=lambda: self.modify_employee(self.id_entry.get(),
                                                                                self.first_name_entry.get(),
                                                                                self.department_combobox.get(),
                                                                                self.job_title_combobox.get(),
                                                                                self.basic_salary_entry.get()))
        button_modify_employee.pack()

    def create_delete_employee_tab(self):

        delete_employee_window = ttk.LabelFrame(self.tabControl, text="Delete Employee")
        delete_employee_window.pack(padx=10, pady=10)

        # Employee ID
        ttk.Label(delete_employee_window, text="Employee ID:").grid(column=0, row=0)
        self.employee_id_entry = ttk.Entry(delete_employee_window, width=30)
        self.employee_id_entry.grid(column=1, row=0)

        # Delete Employee Button
        delete_button = tk.Button(delete_employee_window, text="Delete Employee", command=self.delete_employee)
        delete_button.grid(columnspan=2, pady=10)

    def create_add_employee_tab(self):
        add_employee_window = ttk.LabelFrame(self.tabControl, text="Add Employee")
        add_employee_window.pack(padx=10, pady=10)

        # First Name
        ttk.Label(add_employee_window, text="First Name:").grid(column=0, row=0)
        self.first_name_entry = ttk.Entry(add_employee_window, width=30)
        self.first_name_entry.grid(column=1, row=0)

        # Last Name
        ttk.Label(add_employee_window, text="Last Name:").grid(column=0, row=1)
        self.last_name_entry = ttk.Entry(add_employee_window, width=30)
        self.last_name_entry.grid(column=1, row=1)

        # Gender
        ttk.Label(add_employee_window, text="Gender:").grid(column=0, row=2)
        self.gender_combobox = ttk.Combobox(add_employee_window, values=[gender.value for gender in Gender])
        self.gender_combobox.grid(column=1, row=2)

        # Date of Birth
        ttk.Label(add_employee_window, text="Date of Birth (YYYY-MM-DD):").grid(column=0, row=3)
        self.dob_entry = ttk.Entry(add_employee_window, width=30)
        self.dob_entry.grid(column=1, row=3)

        # Contact Number
        ttk.Label(add_employee_window, text="Contact Number:").grid(column=0, row=4)
        self.contact_entry = ttk.Entry(add_employee_window, width=30)
        self.contact_entry.grid(column=1, row=4)

        # Email Address
        ttk.Label(add_employee_window, text="Email Address:").grid(column=0, row=5)
        self.email_entry = ttk.Entry(add_employee_window, width=30)
        self.email_entry.grid(column=1, row=5)

        # ID
        ttk.Label(add_employee_window, text="ID:").grid(column=0, row=6)
        self.id_entry = ttk.Entry(add_employee_window, width=30)
        self.id_entry.grid(column=1, row=6)

        # Department
        ttk.Label(add_employee_window, text="Department:").grid(column=0, row=7)
        self.department_combobox = ttk.Combobox(add_employee_window,
                                                values=[department.value for department in Department])
        self.department_combobox.grid(column=1, row=7)

        # Job Title
        ttk.Label(add_employee_window, text="Job Title:").grid(column=0, row=8)
        self.job_title_combobox = ttk.Combobox(add_employee_window, values=[job_title.value for job_title in JobTitle])
        self.job_title_combobox.grid(column=1, row=8)

        # Basic Salary
        ttk.Label(add_employee_window, text="Basic Salary:").grid(column=0, row=9)
        self.basic_salary_entry = ttk.Entry(add_employee_window, width=30)
        self.basic_salary_entry.grid(column=1, row=9)

        # Add Employee Button

        # Create a frame for the button
        button_frame = tk.Frame(add_employee_window)
        button_frame.grid(columnspan=2, padx=10)


        # Create the button inside the frame
        button_add_employee = tk.Button(button_frame, text="Add Employee", command=lambda: self.add_employee(
            self.first_name_entry.get(), self.last_name_entry.get(), self.gender_combobox.get(), self.dob_entry.get(),
            self.contact_entry.get(), self.email_entry.get(), self.id_entry.get(), self.department_combobox.get(),
            self.job_title_combobox.get(), self.basic_salary_entry.get()))
        button_add_employee.pack(pady=10)




    def create_display_car_details_tab(self):
        # Create the display car details tab
        display_car_details_window = tk.Toplevel(self.root)
        display_car_details_window.title("Display Car Details")


        # Create a label and entry field for the car ID to display
        label_id = tk.Label(display_car_details_window, text="ID Number:")
        label_id.pack()
        entry_id = tk.Entry(display_car_details_window)
        entry_id.pack()

        # Create a button to display the car details
        button_display_car_details = tk.Button(display_car_details_window, text="Display Car Details",
                                               command=lambda: self.display_car_details(entry_id.get()))
        button_display_car_details.pack()
    def create_sales_details_tab(self):
        # Create the sales details tab
        sales_details_window = tk.Toplevel(self.root)
        sales_details_window.title("Sales Details")

        # Load the employees from the binary file
        employees = self.load_employees()

        # Find the employee with the provided ID number
        for employee in employees:
            if employee.id_number == id_number:
                # Show the sales details of the employee
                sales_details = ""
                for sale in employee.sales:
                    sales_details += f"Car Sold: {sale.car_name}\nSale Price: {sale.sale_price}\n\n"

                tk.messagebox.showinfo("Sales Details", sales_details)
                return


    def add_employee(self, firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress, ID, department, jobTitle, basicSalary):
        firstName = self.first_name_entry.get()
        lastName = self.last_name_entry.get()
        gender = Gender(self.gender_combobox.get())
        dateOfBirth = self.dob_entry.get()
        contactNumber = self.contact_entry.get()
        emailAddress = self.email_entry.get()
        ID = self.id_entry.get()
        department = Department(self.department_combobox.get())
        jobTitle = JobTitle(self.job_title_combobox.get())
        basicSalary = self.basic_salary_entry.get()

        # Create an Employee instance with the provided details
        employee = Employee(firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress, ID, department, jobTitle, basicSalary)

        # Save the employee to a binary file using Pickle
        # Load employees from the binary file
        try:
            with open("employees.pkl", "rb") as file:
                employees = []
                while True:
                    try:
                        employee = pickle.load(file)
                        employees.append(employee)
                    except EOFError:
                        break
                tk.messagebox.showinfo("Success", "Employee added successfully.")
                return employees
        except FileNotFoundError:
            return []

        # Show a success message
        tk.messagebox.showinfo("Success", "Employee added successfully.")

    def delete_employee(self):
        # Get the current working directory
        current_dir = os.getcwd()

        # Construct the file path relative to the current directory
        file_path = os.path.join(current_dir, 'employees.txt')

        # Open the file
        with open(file_path, 'r') as file:
            lines = file.readlines()

        # Find the employee with the given ID
        for i, line in enumerate(lines):
            if line.strip() == employee_id:
                # Remove the employee ID from the list
                del lines[i:i + 3]  # Assuming each employee record spans three lines

                # Write the updated employee data back to the file
                with open('employees.txt', 'w') as file:
                    file.writelines(lines)

                print("Employee deleted successfully.")
                return

        # Employee ID not found
        print("Employee not found.")

    def modify_employee(self):
        # Get the values from the entry fields
        first_name = self.first_name_entry.get()
        last_name = self.last_name_entry.get()
        gender = Gender(self.gender_combobox.get())
        date_of_birth = self.dob_entry.get()
        contact_number = self.contact_entry.get()
        email_address = self.email_entry.get()
        id_number = self.id_entry.get()
        department = Department(self.department_combobox.get())
        job_title = JobTitle(self.job_title_combobox.get())
        basic_salary = self.basic_salary_entry.get()

        # Perform the modification logic
        # Assuming you have a list of employees, you can iterate over the list and find the employee with the matching ID
        for employee in self.employees:
            if employee.id == id_number:
                # Modify the employee attributes
                employee.first_name = first_name
                employee.last_name = last_name
                employee.gender = gender
                employee.date_of_birth = date_of_birth
                employee.contact_number = contact_number
                employee.email_address = email_address
                employee.department = department
                employee.job_title = job_title
                employee.basic_salary = basic_salary
                break

        # Clear the entry fields
        self.first_name_entry.delete(0, tk.END)
        self.last_name_entry.delete(0, tk.END)
        self.gender_combobox.set('')
        self.dob_entry.delete(0, tk.END)
        self.contact_entry.delete(0, tk.END)
        self.email_entry.delete(0, tk.END)
        self.id_entry.delete(0, tk.END)
        self.department_combobox.set('')
        self.job_title_combobox.set('')
        self.basic_salary_entry.delete(0, tk.END)

        # Show a message or perform any other desired actions
        messagebox.showinfo("Modification Successful", "Employee modified successfully.")

    def clear_entry_fields(self):
        # Clear all the entry fields
        entry_first_name.delete(0, tk.END)
        entry_last_name.delete(0, tk.END)
        entry_gender.delete(0, tk.END)
        entry_date_of_birth.delete(0, tk.END)
        entry_contact_number.delete(0, tk.END)
        entry_email_address.delete(0, tk.END)
        entry_id.delete(0, tk.END)
        entry_department.delete(0, tk.END)
        entry_job_title.delete(0, tk.END)
        entry_basic_salary.delete(0, tk.END)

    def load_employees(self):
        # Load employees from the binary file
        try:
            with open("employees.pkl", "rb") as file:
                employees = []
                while True:
                    try:
                        employee = pickle.load(file)
                        employees.append(employee)
                    except EOFError:
                        break
                return employees
        except FileNotFoundError:
            return []

    def save_employees(self, employees):
        # Save employees to the binary file
        with open("employees.pkl", "wb") as file:
            for employee in employees:
                pickle.dump(employee, file)

    def load_cars(self):
        # Load cars from the binary file
        try:
            with open("cars.pkl", "rb") as file:
                cars = []
                while True:
                    try:
                        car = pickle.load(file)
                        cars.append(car)
                    except EOFError:
                        break
                return cars
        except FileNotFoundError:
            return []

    def save_cars(self, cars):
        # Save cars to the binary file
        with open("cars.pkl", "wb") as file:
            for car in cars:
                pickle.dump(car, file)


if __name__ == "__main__":
    CarSalesGUI()

# %%
import tkinter as tk
import tkinter.messagebox as messagebox
import pickle
from tkinter import ttk, Button
from datetime import date
from datetime import datetime
from enum import Enum
import os




class Department(Enum):
    ACCOUNTING = "Accounting"
    IT = "Information Technology"
    MANUFACTURING = "Manufacturing"
    SALES = "Sales"
    MARKETING = "Marketing"
    HR = "Human Resources"
    ADMINISTRATION = "Administration"
    FINANCE = "Finance"
    OPERATIONS = "Operations"
    CUSTOMER_SERVICE = "Customer Service"
    PROCUREMENT = "Procurement"
    QUALITY_ASSURANCE = "Quality Assurance"

class JobTitle(Enum):
    MANAGER = "Manager"
    SALES_PERSON = "Salesperson"
    RECEPTIONIST = "Receptionist"
    MECHANIC = "Mechanic"
    ACCOUNTANT = "Accountant"
    MARKETING_SPECIALIST = "Marketing Specialist"
    HR_OFFICER = "HR Officer"
    IT_SPECIALIST = "IT Specialist"
    ADMINISTRATOR = "Administrator"
    DRIVER = "Driver"

class Gender(Enum):
    MALE = 'Male'
    FEMALE = 'Female'







class Employee:
    def __init__(self, firstName, lastName, gender, dateOfBirth, contactNumber, emailAddress, ID, department, jobTitle, basicSalary):
        self._firstName = firstName
        self._lastName = lastName
        self._gender = gender
        self._dateOfBirth = datetime.strptime(dateOfBirth, "%Y-%m-%d").date()
        self._contactNumber = contactNumber
        self._emailAddress = emailAddress
        self._age = self.calculateAge()
        self._ID = ID
        self._department = department
        self._jobTitle = jobTitle
        self._basicSalary = basicSalary
        self._customers = []
        self.employees = []


    def calculateAge(self):
        today = date.today()
        age = today.year - self._dateOfBirth.year
        if today.month < self._dateOfBirth.month or (
                today.month == self._dateOfBirth.month and today.day < self._dateOfBirth.day):
            age -= 1
        return age


class Car:
    def __init__(self, carID, price, carType, fuelCapacity, maxSpeed, color, mileage, is_new):
        self._carID = carID
        self._price = price
        self._carType = carType
        self._fuelCapacity = fuelCapacity
        self._maxSpeed = maxSpeed
        self._color = color
        self._mileage = mileage
        self._is_new = is_new

class CarSalesGUI:
    def __init__(self):
        self.root = tk.Tk()
        self.tabControl = ttk.Notebook(self.root)
        self.tabControl.pack(expand=1, fill="both")
        self.create_main_tab()
        self.root.mainloop()

    def create_main_tab(self):
        # Create the main tab
        main_tab = ttk.Frame(self.tabControl)
        self.tabControl.add(main_tab, text="Main")

        # Create a label and combobox for selecting an option
        label_option = tk.Label(main_tab, text="Select an option:")
        label_option.pack()

        combo_option = ttk.Combobox(main_tab, values=["Modify Employee", "Delete Employee", "Add Employee",
                                                      "Display Car Details", "Sales Details"])
        combo_option.pack()

        # Create a button to trigger the selected option
        button_execute = tk.Button(main_tab, text="Execute", command=lambda: self.execute_option(combo_option.get()))
        button_execute.pack()

    def execute_option(self, option):
        if option == "Modify Employee":
            self.create_modify_employee_tab()
        elif option == "Delete Employee":
            self.create_delete_employee_tab()
        elif option == "Add Employee":
            self.create_add_employee_tab()
        elif option == "Display Car Details":
            self.create_display_car_details_tab()
        elif option == "Sales Details":
            self.create_sales_details_tab()

    def create_modify_employee_tab(self):
        # Create the modify employee tab
        modify_employee_window = tk.Toplevel(self.root)
        modify_employee_window.title("Modify Employee")

        add_employee_window = ttk.LabelFrame(modify_employee_window, text="Add Employee")
        add_employee_window.pack(padx=10, pady=10)

        # First Name
        ttk.Label(add_employee_window, text="First Name:").grid(column=0, row=0)
        self.first_name_entry = ttk.Entry(add_employee_window, width=30)
        self.first_name_entry.grid(column=1, row=0)

        # Last Name
        ttk.Label(add_employee_window, text="Last Name:").grid(column=0, row=1)
        self.last_name_entry = ttk.Entry(add_employee_window, width=30)
        self.last_name_entry.grid(column=1, row=1)

        # Gender
        ttk.Label(add_employee_window, text="Gender:").grid(column=0, row=2)
        self.gender_combobox = ttk.Combobox(add_employee_window, values=[gender.value for gender in Gender])
        self.gender_combobox.grid(column=1, row=2)

        # Date of Birth
        ttk.Label(add_employee_window, text="Date of Birth (YYYY-MM-DD):").grid(column=0, row=3)
        self.dob_entry = ttk.Entry(add_employee_window, width=30)
        self.dob_entry.grid(column=1, row=3)

        # Contact Number
        ttk.Label(add_employee_window, text="Contact Number:").grid(column=0, row=4)
        self.contact_entry = ttk.Entry(add_employee_window, width=30)
        self.contact_entry.grid(column=1, row=4)

        # Email Address
        ttk.Label(add_employee_window, text="Email Address:").grid(column=0, row=5)
        self.email_entry = ttk.Entry(add_employee_window, width=30)
        self.email_entry.grid(column=1, row=5)

        # ID
        ttk.Label(add_employee_window, text="ID:").grid(column=0, row=6)
        self.id_entry = ttk.Entry(add_employee_window, width=30)
        self.id_entry.grid(column=1, row=6)

        # Department
        ttk.Label(add_employee_window, text="Department:").grid(column=0, row=7)
        self.department_combobox = ttk.Combobox(add_employee_window,
                                                values=[department.value for department in Department])
        self.department_combobox.grid(column=1, row=7)

        # Job Title
        ttk.Label(add_employee_window, text="Job Title:").grid(column=0, row=8)
        self.job_title_combobox = ttk.Combobox(add_employee_window, values=[job_title.value for job_title in JobTitle])
        self.job_title_combobox.grid(column=1, row=8)

        # Basic Salary
        ttk.Label(add_employee_window, text="Basic Salary:").grid(column=0, row=9)
        self.basic_salary_entry = ttk.Entry(add_employee_window, width=30)
        self.basic_salary_entry.grid(column=1, row=9)

        # Create a button to modify the employee
        button_modify_employee = tk.Button(modify_employee_window, text="Modify Employee",
                                           command=lambda: self.modify_employee(self.id_entry.get(),
                                                                                self.first_name_entry.get(),
                                                                                self.department_combobox.get(),
                                                                                self.job_title_combobox.get(),
                                                                                self.basic_salary_entry.get()))
        button_modify_employee.pack()

    def create_delete_employee_tab(self):

        delete_employee_window = ttk.LabelFrame(self.tabControl, text="Delete Employee")
        delete_employee_window.pack(padx=10, pady=10)

        # Employee ID
        ttk.Label(delete_employee_window, text="Employee ID:").grid(column=0, row=0)
        self.employee_id_entry = ttk.Entry(delete_employee_window, width=30)
        self.employee_id_entry.grid(column=1, row=0)

        # Delete Employee Button
        delete_button = tk.Button(delete_employee_window, text="Delete Employee", command=self.delete_employee)
        delete_button.grid(columnspan=2, pady=10)

    def create_add_employee_tab(self):
        add_employee_window = ttk.LabelFrame(self.tabControl, text="Add Employee")
        add_employee_window.pack(padx=10, pady=10)

        # First Name
        ttk.Label(add_employee_window, text="First Name:").grid(column=0, row=0)
        self.first_name_entry = ttk.Entry(add_employee_window, width=30)
        self.first_name_entry.grid(column=1, row=0)

        # Last Name
        ttk.Label(add_employee_window, text="Last Name:").grid(column=0, row=1)
        self.last_name_entry = ttk.Entry(add_employee_window, width=30)
        self.last_name_entry.grid(column=1, row=1)

        # Gender
        ttk.Label(add_employee_window, text="Gender:").grid(column=0, row=2)
        self.gender_combobox = ttk.Combobox(add_employee_window, values=[gender.value for gender in Gender])
        self.gender_combobox.grid(column=1, row=2)

        # Date of Birth
        ttk.Label(add_employee_window, text="Date of Birth (YYYY-MM-DD):").grid(column=0, row=3)
        self.dob_entry = ttk.Entry(add_employee_window, width=30)
        self.dob_entry.grid(column=1, row=3)

        # Contact Number
        ttk.Label(add_employee_window, text="Contact Number:").grid(column=0, row=4)
        self.contact_entry = ttk.Entry(add_employee_window, width=30)
        self.contact_entry.grid(column=1, row=4)

        # Email Address
        ttk.Label(add_employee_window, text="Email Address:").grid(column=0, row=5)
        self.email_entry = ttk.Entry(add_employee_window, width=30)
        self.email_entry.grid(column=1, row=5)

        # ID
        ttk.Label(add_employee_window, text="ID:").grid(column=0, row=6)
        self.id_entry = ttk.Entry(add_employee_window, width=30)
        self.id_entry.grid(column=1, row=6)

        # Department
        ttk.Label(add_employee_window, text="Department:").grid(column=0, row=7)
        self.department_combobox = ttk.Combobox(add_employee_window,
                                                values=[department.value for department in Department])
        self.department_combobox.grid(column=1, row=7)

        # Job Title
        ttk.Label(add_employee_window, text="Job Title:").grid(column=0, row=8)
        self.job_title_combobox = ttk.Combobox(add_employee_window, values=[job_title.value for job_title in JobTitle])
        self.job_title_combobox.grid(column=1, row=8)

        # Basic Salary
        ttk.Label(add_employee_window, text="Basic Salary:").grid(column=0, row=9)
        self.basic_salary_entry = ttk.Entry(add_employee_window, width=30)
        self.basic_salary_entry.grid(column=1, row=9)

        # Add Employee Button

        # Create a frame for the button
        button_frame = tk.Frame(add_employee_window)
        button_frame.grid(columnspan=2, padx=10)


        # Create the button inside the frame
        button_add_employee = tk.Button(button_frame, text="Add Employee", command=lambda: self.add_employee(
            self.first_name_entry.get(), self.last_name_entry.get(), self.gender_combobox.get(), self.dob_entry.get(),
            self.contact_entry.get(), self.email_entry.get(), self.id_entry.get(), self.department_combobox.get(),
            self.job_title_combobox.get(), self.basic_salary_entry.get()))
        button_add_employee.pack(pady=10)




    def create_display_car_details_tab(self):
        # Create the display car details tab
        display_car_details_window = tk.Toplevel(self.root)
        display_car_details_window.title("Display Car Details")


        # Create a label and entry field for the car ID to display
        label_id = tk.Label(display_car_details_window, text="ID Number:")
        label_id.pack()
        entry_id = tk.Entry(display_car_details_window)
        entry_id.pack()

        # Create a button to display the car details
        button_display_car_details = tk.Button(display_car_details_window, text="Display Car Details",
                                               command=lambda: self.display_car_details(entry_id.get()))
        button_display_car_details.pack()
    def create_sales_details_tab(self):
        # Create the sales details tab
        sales_details_window = tk.Toplevel(self.root)
        sales_details_window.title("Sales Details")

        # Load the employees from the binary file
        employees = self.load_employees()

        # Find the employee with the provided ID number
        for employee in employees:
            if employee.id_number == id_number:
                # Show the sales details of the employee
                sales_details = ""
                for sale in employee.sales:
                    sales_details += f"Car Sold: {sale.car_name}\nSale Price: {sale.sale_price}\n\n"

                tk.messagebox.showinfo("Sales Details", sales_details)
                return


    def add_employee(self, firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress, ID, department, jobTitle, basicSalary):
        firstName = self.first_name_entry.get()
        lastName = self.last_name_entry.get()
        gender = Gender(self.gender_combobox.get())
        dateOfBirth = self.dob_entry.get()
        contactNumber = self.contact_entry.get()
        emailAddress = self.email_entry.get()
        ID = self.id_entry.get()
        department = Department(self.department_combobox.get())
        jobTitle = JobTitle(self.job_title_combobox.get())
        basicSalary = self.basic_salary_entry.get()

        # Create an Employee instance with the provided details
        employee = Employee(firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress, ID, department, jobTitle, basicSalary)

        # Save the employee to a binary file using Pickle
        with open("employees.pkl", "ab") as file:
            pickle.dump(employee, file)

        # Show a success message
        tk.messagebox.showinfo("Success", "Employee added successfully.")

    def delete_employee(self):
        # Get the current working directory
        current_dir = os.getcwd()

        # Construct the file path relative to the current directory
        file_path = os.path.join(current_dir, 'employees.txt')

        # Open the file
        with open(file_path, 'r') as file:
            lines = file.readlines()

        # Find the employee with the given ID
        for i, line in enumerate(lines):
            if line.strip() == employee_id:
                # Remove the employee ID from the list
                del lines[i:i + 3]  # Assuming each employee record spans three lines

                # Write the updated employee data back to the file
                with open('employees.txt', 'w') as file:
                    file.writelines(lines)

                print("Employee deleted successfully.")
                return

        # Employee ID not found
        print("Employee not found.")

    def modify_employee(self):
        # Get the values from the entry fields
        first_name = self.first_name_entry.get()
        last_name = self.last_name_entry.get()
        gender = Gender(self.gender_combobox.get())
        date_of_birth = self.dob_entry.get()
        contact_number = self.contact_entry.get()
        email_address = self.email_entry.get()
        id_number = self.id_entry.get()
        department = Department(self.department_combobox.get())
        job_title = JobTitle(self.job_title_combobox.get())
        basic_salary = self.basic_salary_entry.get()

        # Perform the modification logic
        # Assuming you have a list of employees, you can iterate over the list and find the employee with the matching ID
        for employee in self.employees:
            if employee.id == id_number:
                # Modify the employee attributes
                employee.first_name = first_name
                employee.last_name = last_name
                employee.gender = gender
                employee.date_of_birth = date_of_birth
                employee.contact_number = contact_number
                employee.email_address = email_address
                employee.department = department
                employee.job_title = job_title
                employee.basic_salary = basic_salary
                break

        # Clear the entry fields
        self.first_name_entry.delete(0, tk.END)
        self.last_name_entry.delete(0, tk.END)
        self.gender_combobox.set('')
        self.dob_entry.delete(0, tk.END)
        self.contact_entry.delete(0, tk.END)
        self.email_entry.delete(0, tk.END)
        self.id_entry.delete(0, tk.END)
        self.department_combobox.set('')
        self.job_title_combobox.set('')
        self.basic_salary_entry.delete(0, tk.END)

        # Show a message or perform any other desired actions
        messagebox.showinfo("Modification Successful", "Employee modified successfully.")

    def clear_entry_fields(self):
        # Clear all the entry fields
        entry_first_name.delete(0, tk.END)
        entry_last_name.delete(0, tk.END)
        entry_gender.delete(0, tk.END)
        entry_date_of_birth.delete(0, tk.END)
        entry_contact_number.delete(0, tk.END)
        entry_email_address.delete(0, tk.END)
        entry_id.delete(0, tk.END)
        entry_department.delete(0, tk.END)
        entry_job_title.delete(0, tk.END)
        entry_basic_salary.delete(0, tk.END)

    def load_employees(self):
        # Load employees from the binary file
        try:
            with open("employees.pkl", "rb") as file:
                employees = []
                while True:
                    try:
                        employee = pickle.load(file)
                        employees.append(employee)
                    except EOFError:
                        break
                return employees
        except FileNotFoundError:
            return []

    def save_employees(self, employees):
        # Save employees to the binary file
        with open("employees.pkl", "wb") as file:
            for employee in employees:
                pickle.dump(employee, file)

    def load_cars(self):
        # Load cars from the binary file
        try:
            with open("cars.pkl", "rb") as file:
                cars = []
                while True:
                    try:
                        car = pickle.load(file)
                        cars.append(car)
                    except EOFError:
                        break
                return cars
        except FileNotFoundError:
            return []

    def save_cars(self, cars):
        # Save cars to the binary file
        with open("cars.pkl", "wb") as file:
            for car in cars:
                pickle.dump(car, file)


if __name__ == "__main__":
    CarSalesGUI()

# %%
import tkinter as tk
import tkinter.messagebox as messagebox
import pickle
from tkinter import ttk, Button
from datetime import date
from datetime import datetime
from enum import Enum




class Department(Enum):
    ACCOUNTING = "Accounting"
    IT = "Information Technology"
    MANUFACTURING = "Manufacturing"
    SALES = "Sales"
    MARKETING = "Marketing"
    HR = "Human Resources"
    ADMINISTRATION = "Administration"
    FINANCE = "Finance"
    OPERATIONS = "Operations"
    CUSTOMER_SERVICE = "Customer Service"
    PROCUREMENT = "Procurement"
    QUALITY_ASSURANCE = "Quality Assurance"

class JobTitle(Enum):
    MANAGER = "Manager"
    SALES_PERSON = "Salesperson"
    RECEPTIONIST = "Receptionist"
    MECHANIC = "Mechanic"
    ACCOUNTANT = "Accountant"
    MARKETING_SPECIALIST = "Marketing Specialist"
    HR_OFFICER = "HR Officer"
    IT_SPECIALIST = "IT Specialist"
    ADMINISTRATOR = "Administrator"
    DRIVER = "Driver"

class Gender(Enum):
    MALE = 'Male'
    FEMALE = 'Female'







class Employee:
    def __init__(self, firstName, lastName, gender, dateOfBirth, contactNumber, emailAddress, ID, department, jobTitle, basicSalary):
        self._firstName = firstName
        self._lastName = lastName
        self._gender = gender
        self._dateOfBirth = datetime.strptime(dateOfBirth, "%Y-%m-%d").date()
        self._contactNumber = contactNumber
        self._emailAddress = emailAddress
        self._age = self.calculateAge()
        self._ID = ID
        self._department = department
        self._jobTitle = jobTitle
        self._basicSalary = basicSalary
        self._customers = []

    def calculateAge(self):
        today = date.today()
        age = today.year - self._dateOfBirth.year
        if today.month < self._dateOfBirth.month or (
                today.month == self._dateOfBirth.month and today.day < self._dateOfBirth.day):
            age -= 1
        return age


class Car:
    def __init__(self, carID, price, carType, fuelCapacity, maxSpeed, color, mileage, is_new):
        self._carID = carID
        self._price = price
        self._carType = carType
        self._fuelCapacity = fuelCapacity
        self._maxSpeed = maxSpeed
        self._color = color
        self._mileage = mileage
        self._is_new = is_new

class CarSalesGUI:
    def __init__(self):
        self.root = tk.Tk()
        self.tabControl = ttk.Notebook(self.root)
        self.tabControl.pack(expand=1, fill="both")
        self.create_main_tab()
        self.root.mainloop()

    def create_main_tab(self):
        # Create the main tab
        main_tab = ttk.Frame(self.tabControl)
        self.tabControl.add(main_tab, text="Main")

        # Create a label and combobox for selecting an option
        label_option = tk.Label(main_tab, text="Select an option:")
        label_option.pack()

        combo_option = ttk.Combobox(main_tab, values=["Modify Employee", "Delete Employee", "Add Employee",
                                                      "Display Car Details", "Sales Details"])
        combo_option.pack()

        # Create a button to trigger the selected option
        button_execute = tk.Button(main_tab, text="Execute", command=lambda: self.execute_option(combo_option.get()))
        button_execute.pack()

    def execute_option(self, option):
        if option == "Modify Employee":
            self.create_modify_employee_tab()
        elif option == "Delete Employee":
            self.create_delete_employee_tab()
        elif option == "Add Employee":
            self.create_add_employee_tab()
        elif option == "Display Car Details":
            self.create_display_car_details_tab()
        elif option == "Sales Details":
            self.create_sales_details_tab()

    def create_modify_employee_tab(self):
        # Create the modify employee tab
        modify_employee_window = tk.Toplevel(self.root)
        modify_employee_window.title("Modify Employee")


        # Create labels and entry fields for employee details
        label_id = tk.Label(modify_employee_window, text="ID Number:")
        label_id.pack()
        entry_id = tk.Entry(modify_employee_window)
        entry_id.pack()

        label_name = tk.Label(modify_employee_window, text="Name:")
        label_name.pack()
        entry_name = tk.Entry(modify_employee_window)
        entry_name.pack()

        label_department = tk.Label(modify_employee_window, text="Department:")
        label_department.pack()
        entry_department = tk.Entry(modify_employee_window)
        entry_department.pack()

        label_job_title = tk.Label(modify_employee_window, text="Job Title:")
        label_job_title.pack()
        entry_job_title = tk.Entry(modify_employee_window)
        entry_job_title.pack()

        label_basic_salary = tk.Label(modify_employee_window, text="Basic Salary:")
        label_basic_salary.pack()
        entry_basic_salary = tk.Entry(modify_employee_window)
        entry_basic_salary.pack()

        # Create a button to modify the employee
        button_modify_employee = tk.Button(modify_employee_window, text="Modify Employee",
                                           command=lambda: self.modify_employee(entry_id.get(), entry_name.get(),
                                                                                entry_department.get(),
                                                                                entry_job_title.get(),
                                                                                entry_basic_salary.get()))
        button_modify_employee.pack()

    def create_delete_employee_tab(self):
        # Create the delete employee tab
        delete_employee_window = tk.Toplevel(self.root)
        delete_employee_window.title("Delete Employee")

        # Create a label and entry field for the employee ID to delete
        label_id = tk.Label(delete_employee_window, text="ID Number:")
        label_id.pack()
        entry_id = tk.Entry(delete_employee_window)
        entry_id.pack()

        # Create a button to delete the employee
        button_delete_employee = tk.Button(delete_employee_window, text="Delete Employee",
                                           command=lambda: self.delete_employee(entry_id.get()))
        button_delete_employee.pack()
    def create_add_employee_tab(self):
        add_employee_window = ttk.LabelFrame(self.tabControl, text="Add Employee")
        add_employee_window.pack(padx=10, pady=10)

        # First Name
        ttk.Label(add_employee_window, text="First Name:").grid(column=0, row=0)
        self.first_name_entry = ttk.Entry(add_employee_window, width=30)
        self.first_name_entry.grid(column=1, row=0)

        # Last Name
        ttk.Label(add_employee_window, text="Last Name:").grid(column=0, row=1)
        self.last_name_entry = ttk.Entry(add_employee_window, width=30)
        self.last_name_entry.grid(column=1, row=1)

        # Gender
        ttk.Label(add_employee_window, text="Gender:").grid(column=0, row=2)
        self.gender_combobox = ttk.Combobox(add_employee_window, values=[gender.value for gender in Gender])
        self.gender_combobox.grid(column=1, row=2)

        # Date of Birth
        ttk.Label(add_employee_window, text="Date of Birth (YYYY-MM-DD):").grid(column=0, row=3)
        self.dob_entry = ttk.Entry(add_employee_window, width=30)
        self.dob_entry.grid(column=1, row=3)

        # Contact Number
        ttk.Label(add_employee_window, text="Contact Number:").grid(column=0, row=4)
        self.contact_entry = ttk.Entry(add_employee_window, width=30)
        self.contact_entry.grid(column=1, row=4)

        # Email Address
        ttk.Label(add_employee_window, text="Email Address:").grid(column=0, row=5)
        self.email_entry = ttk.Entry(add_employee_window, width=30)
        self.email_entry.grid(column=1, row=5)

        # ID
        ttk.Label(add_employee_window, text="ID:").grid(column=0, row=6)
        self.id_entry = ttk.Entry(add_employee_window, width=30)
        self.id_entry.grid(column=1, row=6)

        # Department
        ttk.Label(add_employee_window, text="Department:").grid(column=0, row=7)
        self.department_combobox = ttk.Combobox(add_employee_window,
                                                values=[department.value for department in Department])
        self.department_combobox.grid(column=1, row=7)

        # Job Title
        ttk.Label(add_employee_window, text="Job Title:").grid(column=0, row=8)
        self.job_title_combobox = ttk.Combobox(add_employee_window, values=[job_title.value for job_title in JobTitle])
        self.job_title_combobox.grid(column=1, row=8)

        # Basic Salary
        ttk.Label(add_employee_window, text="Basic Salary:").grid(column=0, row=9)
        self.basic_salary_entry = ttk.Entry(add_employee_window, width=30)
        self.basic_salary_entry.grid(column=1, row=9)

        # Add Employee Button

        # Create a frame for the button
        button_frame = tk.Frame(add_employee_window)
        button_frame.grid(columnspan=2, padx=10)


        # Create the button inside the frame
        button_add_employee = tk.Button(button_frame, text="Add Employee", command=lambda: self.add_employee(
            self.first_name_entry.get(), self.last_name_entry.get(), self.gender_combobox.get(), self.dob_entry.get(),
            self.contact_entry.get(), self.email_entry.get(), self.id_entry.get(), self.department_combobox.get(),
            self.job_title_combobox.get(), self.basic_salary_entry.get()))
        button_add_employee.pack(pady=10)




def create_display_car_details_tab(self):
        # Create the display car details tab
        display_car_details_window = tk.Toplevel(self.root)
        display_car_details_window.title("Display Car Details")


        # Create a label and entry field for the car ID to display
        label_id = tk.Label(display_car_details_window, text="ID Number:")
        label_id.pack()
        entry_id = tk.Entry(display_car_details_window)
        entry_id.pack()

        # Create a button to display the car details
        button_display_car_details = tk.Button(display_car_details_window, text="Display Car Details",
                                               command=lambda: self.display_car_details(entry_id.get()))
        button_display_car_details.pack()
def create_sales_details_tab(self):
        # Create the sales details tab
        sales_details_window = tk.Toplevel(self.root)
        sales_details_window.title("Sales Details")

        # Load the employees from the binary file
        employees = self.load_employees()

        # Find the employee with the provided ID number
        for employee in employees:
            if employee.id_number == id_number:
                # Show the sales details of the employee
                sales_details = ""
                for sale in employee.sales:
                    sales_details += f"Car Sold: {sale.car_name}\nSale Price: {sale.sale_price}\n\n"

                tk.messagebox.showinfo("Sales Details", sales_details)
                return


    def add_employee(self, firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress, ID, department, jobTitle, basicSalary):
        firstName = self.first_name_entry.get()
        lastName = self.last_name_entry.get()
        gender = Gender(self.gender_combobox.get())
        dateOfBirth = self.dob_entry.get()
        contactNumber = self.contact_entry.get()
        emailAddress = self.email_entry.get()
        ID = self.id_entry.get()
        department = Department(self.department_combobox.get())
        jobTitle = JobTitle(self.job_title_combobox.get())
        basicSalary = self.basic_salary_entry.get()

        # Create an Employee instance with the provided details
        employee = Employee(firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress, ID, department, jobTitle, basicSalary)

        # Save the employee to a binary file using Pickle
        with open("employees.pkl", "ab") as file:
            pickle.dump(employee, file)

        # Show a success message
        tk.messagebox.showinfo("Success", "Employee added successfully.")

    def clear_entry_fields(self):
        # Clear all the entry fields
        entry_first_name.delete(0, tk.END)
        entry_last_name.delete(0, tk.END)
        entry_gender.delete(0, tk.END)
        entry_date_of_birth.delete(0, tk.END)
        entry_contact_number.delete(0, tk.END)
        entry_email_address.delete(0, tk.END)
        entry_id.delete(0, tk.END)
        entry_department.delete(0, tk.END)
        entry_job_title.delete(0, tk.END)
        entry_basic_salary.delete(0, tk.END)

    def load_employees(self):
        # Load employees from the binary file
        try:
            with open("employees.pkl", "rb") as file:
                employees = []
                while True:
                    try:
                        employee = pickle.load(file)
                        employees.append(employee)
                    except EOFError:
                        break
                return employees
        except FileNotFoundError:
            return []

    def save_employees(self, employees):
        # Save employees to the binary file
        with open("employees.pkl", "wb") as file:
            for employee in employees:
                pickle.dump(employee, file)

    def load_cars(self):
        # Load cars from the binary file
        try:
            with open("cars.pkl", "rb") as file:
                cars = []
                while True:
                    try:
                        car = pickle.load(file)
                        cars.append(car)
                    except EOFError:
                        break
                return cars
        except FileNotFoundError:
            return []

    def save_cars(self, cars):
        # Save cars to the binary file
        with open("cars.pkl", "wb") as file:
            for car in cars:
                pickle.dump(car, file)


if __name__ == "__main__":
    CarSalesGUI()

# %%
    def create_add_employee_tab(self):
        add_employee_window = ttk.LabelFrame(self.tabControl, text="Add Employee")
        add_employee_window.pack(padx=10, pady=10)

        # First Name
        ttk.Label(add_employee_window, text="First Name:").grid(column=0, row=0)
        self.first_name_entry = ttk.Entry(add_employee_window, width=30).grid(column=1, row=0)

        # Last Name
        ttk.Label(add_employee_window, text="Last Name:").grid(column=0, row=1)
        self.last_name_entry = ttk.Entry(add_employee_window, width=30)
        self.last_name_entry.grid(column=1, row=1)

        # Gender
        ttk.Label(add_employee_window, text="Gender:").grid(column=0, row=2)
        self.gender_combobox = ttk.Combobox(add_employee_window, values=[gender.value for gender in Gender])
        self.gender_combobox.grid(column=1, row=2)

        # Date of Birth
        ttk.Label(add_employee_window, text="Date of Birth (YYYY-MM-DD):").grid(column=0, row=3)
        self.dob_entry = ttk.Entry(add_employee_window, width=30)
        self.dob_entry.grid(column=1, row=3)

        # Contact Number
        ttk.Label(add_employee_window, text="Contact Number:").grid(column=0, row=4)
        self.contact_entry = ttk.Entry(add_employee_window, width=30)
        self.contact_entry.grid(column=1, row=4)

        # Email Address
        ttk.Label(add_employee_window, text="Email Address:").grid(column=0, row=5)
        self.email_entry = ttk.Entry(add_employee_window, width=30)
        self.email_entry.grid(column=1, row=5)

        # ID
        ttk.Label(add_employee_window, text="ID:").grid(column=0, row=6)
        self.id_entry = ttk.Entry(add_employee_window, width=30)
        self.id_entry.grid(column=1, row=6)

        # Department
        ttk.Label(add_employee_window, text="Department:").grid(column=0, row=7)
        self.department_combobox = ttk.Combobox(add_employee_window, values=[department.value for department in Department])
        self.department_combobox.grid(column=1, row=7)

        # Job Title
        ttk.Label(add_employee_window, text="Job Title:").grid(column=0, row=8)
        self.job_title_combobox = ttk.Combobox(add_employee_window, values=[job_title.value for job_title in JobTitle])
        self.job_title_combobox.grid(column=1, row=8)

        # Basic Salary
        ttk.Label(add_employee_window, text="Basic Salary:").grid(column=0, row=9)
        self.basic_salary_entry = ttk.Entry(add_employee_window, width=30)
        self.basic_salary_entry.grid(column=1, row=9)

        # Add Employee Button

        # Create a frame for the button
        button_frame = tk.Frame(add_employee_window)
        button_frame.grid(columnspan=2, padx=10)

        # Create the button inside the frame
        button_add_employee = tk.Button(button_frame, text="Add Employee", command=lambda: self.add_employee(
            self.first_name_entry.get(), self.last_name_entry.get(), self.gender_combobox.get(), self.dob_entry.get(),
            self.contact_entry.get(), self.email_entry.get(), self.id_entry.get(), self.department_combobox.get(),
            self.job_title_combobox.get(), self.basic_salary_entry.get()
        ))
        button_add_employee.pack(pady=10)

# %%
        elif option == "Add Employee":
            self.create_add_employee_tab()

# %%
        # Create labels and entry fields for employee details
        label_first_name = tk.Label(add_employee_window, text="First Name:")
        label_first_name.pack()
        entry_first_name = tk.Entry(add_employee_window)
        entry_first_name.pack()

        #label_last_name = tk.Label(add_employee_window, text="Last Name:")
        #label_last_name.pack()
        #entry_last_name = tk.Entry(add_employee_window)
        #entry_last_name.pack()

        ttk.Label(add_employee_window, text="Gender:").grid(column=0, row=2)
        self.gender_combobox = ttk.Combobox(add_employee_window, values=[gender.value for gender in Gender])
        self.gender_combobox.grid(column=1, row=2)

        label_gender = tk.Label(add_employee_window, text="Gender:")
        label_gender.pack()
        entry_gender = tk.Entry(add_employee_window)
        entry_gender.pack()

        label_date_of_birth = tk.Label(add_employee_window, text="Date of Birth(as year-month-day):")
        label_date_of_birth.pack()
        entry_date_of_birth = tk.Entry(add_employee_window)
        entry_date_of_birth.pack()

        label_contact_number = tk.Label(add_employee_window, text="Contact Number:")
        label_contact_number.pack()
        entry_contact_number = tk.Entry(add_employee_window)
        entry_contact_number.pack()

        label_email_address = tk.Label(add_employee_window, text="Email Address:")
        label_email_address.pack()
        entry_email_address = tk.Entry(add_employee_window)
        entry_email_address.pack()

        label_id = tk.Label(add_employee_window, text="ID Number:")
        label_id.pack()
        entry_id = tk.Entry(add_employee_window)
        entry_id.pack()

        ttk.Label(add_employee_window, text="Department:").grid(column=0, row=7)
        self.department_combobox = ttk.Combobox(add_employee_window, values=[department.value for department in Department])
        self.department_combobox.grid(column=1, row=7)

        ttk.Label(add_employee_window, text="Job Title:").grid(column=0, row=8)
        self.job_title_combobox = ttk.Combobox(add_employee_window, values=[job_title.value for job_title in JobTitle])
        self.job_title_combobox.grid(column=1, row=8)

        label_basic_salary = tk.Label(add_employee_window, text="Basic Salary:")
        label_basic_salary.pack()
        entry_basic_salary = tk.Entry(add_employee_window)
        entry_basic_salary.pack()

# %%
import tkinter as tk
import pickle
from tkinter import ttk, Button
from datetime import date


class Employee:
    def __init__(self, firstName, lastName, gender, dateOfBirth, contactNumber, emailAddress, ID, department, jobTitle, basicSalary):
        self._firstName = firstName
        self._lastName = lastName
        self._gender = gender
        self._dateOfBirth = dateOfBirth
        self._contactNumber = contactNumber
        self._emailAddress = emailAddress
        self._age = self.calculateAge()
        self._ID = ID
        self._department = department
        self._jobTitle = jobTitle
        self._basicSalary = basicSalary
        self._customers = []

    def calculateAge(self):
        today = date.today()
        age = today.year - self._dateOfBirth.year
        if today.month < self._dateOfBirth.month or (
                today.month == self._dateOfBirth.month and today.day < self._dateOfBirth.day):
            age -= 1
        return age


class Car:
    def __init__(self, carID, price, carType, fuelCapacity, maxSpeed, color, mileage, is_new):
        self._carID = carID
        self._price = price
        self._carType = carType
        self._fuelCapacity = fuelCapacity
        self._maxSpeed = maxSpeed
        self._color = color
        self._mileage = mileage
        self._is_new = is_new

class CarSalesGUI:
    def __init__(self):
        self.root = tk.Tk()
        self.tabControl = ttk.Notebook(self.root)
        self.tabControl.pack(expand=1, fill="both")
        self.create_main_tab()
        self.root.mainloop()

    def create_main_tab(self):
        # Create the main tab
        main_tab = ttk.Frame(self.tabControl)
        self.tabControl.add(main_tab, text="Main")

        # Create a label and combobox for selecting an option
        label_option = tk.Label(main_tab, text="Select an option:")
        label_option.pack()

        combo_option = ttk.Combobox(main_tab, values=["Modify Employee", "Delete Employee", "Add Employee",
                                                      "Display Car Details", "Sales Details"])
        combo_option.pack()

        # Create a button to trigger the selected option
        button_execute = tk.Button(main_tab, text="Execute", command=lambda: self.execute_option(combo_option.get()))
        button_execute.pack()

    def execute_option(self, option):
        if option == "Modify Employee":
            self.create_modify_employee_tab()
        elif option == "Delete Employee":
            self.create_delete_employee_tab()
        elif option == "Add Employee":
            self.create_add_employee_tab()
        elif option == "Display Car Details":
            self.create_display_car_details_tab()
        elif option == "Sales Details":
            self.create_sales_details_tab()

    def create_modify_employee_tab(self):
        # Create the modify employee tab
        modify_employee_window = tk.Toplevel(self.root)
        modify_employee_window.title("Modify Employee")


        # Create labels and entry fields for employee details
        label_id = tk.Label(modify_employee_window, text="ID Number:")
        label_id.pack()
        entry_id = tk.Entry(modify_employee_window)
        entry_id.pack()

        label_name = tk.Label(modify_employee_window, text="Name:")
        label_name.pack()
        entry_name = tk.Entry(modify_employee_window)
        entry_name.pack()

        label_department = tk.Label(modify_employee_window, text="Department:")
        label_department.pack()
        entry_department = tk.Entry(modify_employee_window)
        entry_department.pack()

        label_job_title = tk.Label(modify_employee_window, text="Job Title:")
        label_job_title.pack()
        entry_job_title = tk.Entry(modify_employee_window)
        entry_job_title.pack()

        label_basic_salary = tk.Label(modify_employee_window, text="Basic Salary:")
        label_basic_salary.pack()
        entry_basic_salary = tk.Entry(modify_employee_window)
        entry_basic_salary.pack()

        # Create a button to modify the employee
        button_modify_employee = tk.Button(modify_employee_window, text="Modify Employee",
                                           command=lambda: self.modify_employee(entry_id.get(), entry_name.get(),
                                                                                entry_department.get(),
                                                                                entry_job_title.get(),
                                                                                entry_basic_salary.get()))
        button_modify_employee.pack()

    def create_delete_employee_tab(self):
        # Create the delete employee tab
        delete_employee_window = tk.Toplevel(self.root)
        delete_employee_window.title("Delete Employee")

        # Create a label and entry field for the employee ID to delete
        label_id = tk.Label(delete_employee_window, text="ID Number:")
        label_id.pack()
        entry_id = tk.Entry(delete_employee_window)
        entry_id.pack()

        # Create a button to delete the employee
        button_delete_employee = tk.Button(delete_employee_window, text="Delete Employee",
                                           command=lambda: self.delete_employee(entry_id.get()))
        button_delete_employee.pack()
    def create_add_employee_tab(self):
        # Create the add employee tab
        add_employee_window = tk.Toplevel(self.root)
        add_employee_window.title("Add Employee")


        # Create labels and entry fields for employee details
        label_first_name = tk.Label(add_employee_window, text="First Name:")
        label_first_name.pack()
        entry_first_name = tk.Entry(add_employee_window)
        entry_first_name.pack()

        label_last_name = tk.Label(add_employee_window, text="Last Name:")
        label_last_name.pack()
        entry_last_name = tk.Entry(add_employee_window)
        entry_last_name.pack()

        label_gender = tk.Label(add_employee_window, text="Gender:")
        label_gender.pack()
        entry_gender = tk.Entry(add_employee_window)
        entry_gender.pack()

        label_date_of_birth = tk.Label(add_employee_window, text="Date of Birth:")
        label_date_of_birth.pack()
        entry_date_of_birth = tk.Entry(add_employee_window)
        entry_date_of_birth.pack()

        label_contact_number = tk.Label(add_employee_window, text="Contact Number:")
        label_contact_number.pack()
        entry_contact_number = tk.Entry(add_employee_window)
        entry_contact_number.pack()

        label_email_address = tk.Label(add_employee_window, text="Email Address:")
        label_email_address.pack()
        entry_email_address = tk.Entry(add_employee_window)
        entry_email_address.pack()

        label_id = tk.Label(add_employee_window, text="ID Number:")
        label_id.pack()
        entry_id = tk.Entry(add_employee_window)
        entry_id.pack()

        label_department = tk.Label(add_employee_window, text="Department:")
        label_department.pack()
        entry_department = tk.Entry(add_employee_window)
        entry_department.pack()

        label_job_title = tk.Label(add_employee_window, text="Job Title:")
        label_job_title.pack()
        entry_job_title = tk.Entry(add_employee_window)
        entry_job_title.pack()

        label_basic_salary = tk.Label(add_employee_window, text="Basic Salary:")
        label_basic_salary.pack()
        entry_basic_salary = tk.Entry(add_employee_window)
        entry_basic_salary.pack()

        # Create a button to add the employee
        button_add_employee = tk.Button(add_employee_window, text="Add Employee", command=lambda: self.add_employee(
            entry_first_name.get(),
            entry_last_name.get(),
            entry_gender.get(),
            entry_date_of_birth.get(),
            entry_contact_number.get(),
            entry_email_address.get(),
            entry_id.get(),
            entry_department.get(),
            entry_job_title.get(),
            entry_basic_salary.get()))
        button_add_employee.pack()

    def create_display_car_details_tab(self):
        # Create the display car details tab
        display_car_details_window = tk.Toplevel(self.root)
        display_car_details_window.title("Display Car Details")


        # Create a label and entry field for the car ID to display
        label_id = tk.Label(display_car_details_window, text="ID Number:")
        label_id.pack()
        entry_id = tk.Entry(display_car_details_window)
        entry_id.pack()

        # Create a button to display the car details
        button_display_car_details = tk.Button(display_car_details_window, text="Display Car Details",
                                               command=lambda: self.display_car_details(entry_id.get()))
        button_display_car_details.pack()
    def create_sales_details_tab(self):
        # Create the sales details tab
        sales_details_window = tk.Toplevel(self.root)
        sales_details_window.title("Sales Details")

        # Load the employees from the binary file
        employees = self.load_employees()

        # Find the employee with the provided ID number
        for employee in employees:
            if employee.id_number == id_number:
                # Show the sales details of the employee
                sales_details = ""
                for sale in employee.sales:
                    sales_details += f"Car Sold: {sale.car_name}\nSale Price: {sale.sale_price}\n\n"

                tk.messagebox.showinfo("Sales Details", sales_details)
                return


    def add_employee(self, firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress, ID, department, jobTitle, basicSalary):
        # Create an Employee instance with the provided details
        employee = Employee(firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress, ID, department, jobTitle, basicSalary)

        # Save the employee to a binary file using Pickle
        with open("employees.pkl", "ab") as file:
            pickle.dump(employee, file)

        # Show a success message
        tk.messagebox.showinfo("Success", "Employee added successfully.")

    def clear_entry_fields(self):
        # Clear all the entry fields
        entry_first_name.delete(0, tk.END)
        entry_last_name.delete(0, tk.END)
        entry_gender.delete(0, tk.END)
        entry_date_of_birth.delete(0, tk.END)
        entry_contact_number.delete(0, tk.END)
        entry_email_address.delete(0, tk.END)
        entry_id.delete(0, tk.END)
        entry_department.delete(0, tk.END)
        entry_job_title.delete(0, tk.END)
        entry_basic_salary.delete(0, tk.END)

    def load_employees(self):
        # Load employees from the binary file
        try:
            with open("employees.pkl", "rb") as file:
                employees = []
                while True:
                    try:
                        employee = pickle.load(file)
                        employees.append(employee)
                    except EOFError:
                        break
                return employees
        except FileNotFoundError:
            return []

    def save_employees(self, employees):
        # Save employees to the binary file
        with open("employees.pkl", "wb") as file:
            for employee in employees:
                pickle.dump(employee, file)

    def load_cars(self):
        # Load cars from the binary file
        try:
            with open("cars.pkl", "rb") as file:
                cars = []
                while True:
                    try:
                        car = pickle.load(file)
                        cars.append(car)
                    except EOFError:
                        break
                return cars
        except FileNotFoundError:
            return []

    def save_cars(self, cars):
        # Save cars to the binary file
        with open("cars.pkl", "wb") as file:
            for car in cars:
                pickle.dump(car, file)


if __name__ == "__main__":
    CarSalesGUI()

# %%
# Employee class
class Employee:
    def __init__(self, name, id_number, department, job_title, basic_salary):
        self.name = name
        self.id_number = id_number
        self.department = department
        self.job_title = job_title
        self.basic_salary = basic_salary

# Car class
class Car:
    def __init__(self, id_number, price, car_type):
        self.id_number = id_number
        self.price = price
        self.car_type = car_type

# Main window
class MainWindow(tk.Tk):
    def __init__(self):
        tk.Tk.__init__(self)
        self.title("Car Management System")

        # Create the main menu
        self.menu = tk.Menu(self)
        self.menu.add_command(label="Add Employee", command=self.open_add_employee)
        self.menu.add_command(label="Delete Employee", command=self.open_delete_employee)
        self.menu.add_command(label="Modify Employee", command=self.open_modify_employee)
        self.menu.add_command(label="Display Car Details", command=self.open_display_car_details)
        self.menu.add_command(label="Display Sales Details", command=self.open_display_sales_details)
        self.config(menu=self.menu)

    def open_add_employee(self):
        # Create a new window for adding an employee
        add_employee_window = tk.Toplevel(self)
        add_employee_window.title("Add Employee")

        # Create labels and entry fields for employee details
        label_name = tk.Label(add_employee_window, text="Name:")
        label_name.pack()
        entry_name = tk.Entry(add_employee_window)
        entry_name.pack()

        label_id = tk.Label(add_employee_window, text="ID Number:")
        label_id.pack()
        entry_id = tk.Entry(add_employee_window)
        entry_id.pack()

        label_department = tk.Label(add_employee_window, text="Department:")
        label_department.pack()
        entry_department = tk.Entry(add_employee_window)
        entry_department.pack()

        label_job_title = tk.Label(add_employee_window, text="Job Title:")
        label_job_title.pack()
        entry_job_title = tk.Entry(add_employee_window)
        entry_job_title.pack()

        label_basic_salary = tk.Label(add_employee_window, text="Basic Salary:")
        label_basic_salary.pack()
        entry_basic_salary = tk.Entry(add_employee_window)
        entry_basic_salary.pack()

        # Create a button to add the employee
        button_add_employee = tk.Button(add_employee_window, text="Add Employee",
                                        command=lambda: self.add_employee(entry_name.get(), entry_id.get(),
                                                                         entry_department.get(),
                                                                         entry_job_title.get(),
                                                                         entry_basic_salary.get()))
        button_add_employee.pack()

    def open_delete_employee(self):
        # Create a new window for deleting an employee
        delete_employee_window = tk.Toplevel(self)
        delete_employee_window.title("Delete Employee")

        # Create a label and entry field for the employee ID to delete
        label_id = tk.Label(delete_employee_window, text="ID Number:")
        label_id.pack()
        entry_id = tk.Entry(delete_employee_window)
        entry_id.pack()

        # Create a button to delete the employee
        button_delete_employee = tk.Button(delete_employee_window, text="Delete Employee",
                                           command=lambda: self.delete_employee(entry_id.get()))
        button_delete_employee.pack()

    def open_modify_employee(self):
        # Create a new window for modifying an employee
        modify_employee_window = tk.Toplevel(self)
        modify_employee_window.title("Modify Employee")
        # Create labels and entry fields for employee details
        label_id = tk.Label(modify_employee_window, text="ID Number:")
        label_id.pack()
        entry_id = tk.Entry(modify_employee_window)
        entry_id.pack()

        label_name = tk.Label(modify_employee_window, text="Name:")
        label_name.pack()
        entry_name = tk.Entry(modify_employee_window)
        entry_name.pack()

        label_department = tk.Label(modify_employee_window, text="Department:")
        label_department.pack()
        entry_department = tk.Entry(modify_employee_window)
        entry_department.pack()

        label_job_title = tk.Label(modify_employee_window, text="Job Title:")
        label_job_title.pack()
        entry_job_title = tk.Entry(modify_employee_window)
        entry_job_title.pack()

        label_basic_salary = tk.Label(modify_employee_window, text="Basic Salary:")
        label_basic_salary.pack()
        entry_basic_salary = tk.Entry(modify_employee_window)
        entry_basic_salary.pack()

        # Create a button to modify the employee
        button_modify_employee = tk.Button(modify_employee_window, text="Modify Employee",
                                           command=lambda: self.modify_employee(entry_id.get(), entry_name.get(),
                                                                                entry_department.get(),
                                                                                entry_job_title.get(),
                                                                                entry_basic_salary.get()))
        button_modify_employee.pack()

    def open_display_car_details(self):
        # Create a new window for displaying car details
        display_car_details_window = tk.Toplevel(self)
        display_car_details_window.title("Display Car Details")

        # Create a label and entry field for the car ID to display
        label_id = tk.Label(display_car_details_window, text="ID Number:")
        label_id.pack()
        entry_id = tk.Entry(display_car_details_window)
        entry_id.pack()

        # Create a button to display the car details
        button_display_car_details = tk.Button(display_car_details_window, text="Display Car Details",
                                               command=lambda: self.display_car_details(entry_id.get()))
        button_display_car_details.pack()

    def open_display_sales_details(self):
        # Create a new window for displaying sales details
        display_sales_details_window = tk.Toplevel(self)
        display_sales_details_window.title("Display Sales Details")

        # Create a label and entry field for the employee ID to display sales details
        label_id = tk.Label(display_sales_details_window, text="ID Number:")
        label_id.pack()
        entry_id = tk.Entry(display_sales_details_window)
        entry_id.pack()

        # Create a button to display the sales details
        button_display_sales_details = tk.Button(display_sales_details_window, text="Display Sales Details",
                                                 command=lambda: self.display_sales_details(entry_id.get()))
        button_display_sales_details.pack()

    def add_employee(self, firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress, ID, department, jobTitle, basicSalary):
        # Create an Employee instance with the provided details
        employee = Employee(firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress, ID, department, jobTitle, basicSalary)

        # Save the employee to a binary file using Pickle
        with open("employees.pkl", "ab") as file:
            pickle.dump(employee, file)

        # Show a success message
        tk.messagebox.showinfo("Success", "Employee added successfully.")

    def delete_employee(self, id_number):
        # Load the employees from the binary file
        employees = self.load_employees()

        # Find the employee with the provided ID number
        for employee in employees:
            if employee.id_number == id_number:
                # Remove the employee from the list
                employees.remove(employee)

                # Save the updated list back to the binary file
                self.save_employees(employees)

                # Show a success message
                tk.messagebox.showinfo
                tk.messagebox.showinfo("Success", "Employee deleted successfully.")
                return

        # Show an error message if the employee was not found
        tk.messagebox.showerror("Error", "Employee not found.")

    def modify_employee(self, id_number, name, department, job_title, basic_salary):
        # Load the employees from the binary file
        employees = self.load_employees()

        # Find the employee with the provided ID number
        for employee in employees:
            if employee.id_number == id_number:
                # Modify the employee details
                employee.name = name
                employee.department = department
                employee.job_title = job_title
                employee.basic_salary = basic_salary

                # Save the updated list back to the binary file
                self.save_employees(employees)

                # Show a success message
                tk.messagebox.showinfo("Success", "Employee modified successfully.")
                return

        # Show an error message if the employee was not found
        tk.messagebox.showerror("Error", "Employee not found.")

    def display_car_details(self, id_number):
        # Load the cars from the binary file
        cars = self.load_cars()

        # Find the car with the provided ID number
        for car in cars:
            if car.id_number == id_number:
                # Show the car details
                tk.messagebox.showinfo("Car Details", f"ID Number: {car.id_number}\nPrice: {car.price}\nType: {car.car_type}")
                return

        # Show an error message if the car was not found
        tk.messagebox.showerror("Error", "Car not found.")

    def display_sales_details(self, id_number):
        # Load the employees from the binary file
        employees = self.load_employees()

        # Find the employee with the provided ID number
        for employee in employees:
            if employee.id_number == id_number:
                # Show the sales details of the employee
                sales_details = ""
                for sale in employee.sales:
                    sales_details += f"Car Sold: {sale.car_name}\nSale Price: {sale.sale_price}\n\n"

                tk.messagebox.showinfo("Sales Details", sales_details)
                return

        # Show an error message if the employee was not found
        tk.messagebox.showerror("Error", "Employee not found.")

    def load_employees(self):
        # Load employees from the binary file
        try:
            with open("employees.pkl", "rb") as file:
                employees = []
                while True:
                    try:
                        employee = pickle.load(file)
                        employees.append(employee)
                    except EOFError:
                        break
                return employees
        except FileNotFoundError:
            return []

    def save_employees(self, employees):
        # Save employees to the binary file
        with open("employees.pkl", "wb") as file:
            for employee in employees:
                pickle.dump(employee, file)

    def load_cars(self):
        # Load cars from the binary file
        try:
            with open("cars.pkl", "rb") as file:
                cars = []
                while True:
                    try:
                        car = pickle.load(file)
                        cars.append(car)
                    except EOFError:
                        break
                return cars
        except FileNotFoundError:
            return []

    def save_cars(self, cars):
        # Save cars to the binary file
        with open("cars.pkl", "wb") as file:
          for car in cars:
                pickle.dump(car, file)

# Create the main window
if __name__ == "__main__":
    root = MainWindow()
    root.mainloop()

# %%
#code 2 
import tkinter as tk
import pickle

# Employee class
class Employee:
    def __init__(self, name, id_number, department, job_title, basic_salary):
        self.name = name
        self.id_number = id_number
        self.department = department
        self.job_title = job_title
        self.basic_salary = basic_salary

# Car class
class Car:
    def __init__(self, id_number, price, car_type):
        self.id_number = id_number
        self.price = price
        self.car_type = car_type

# Main window
class MainWindow(tk.Tk):
    def __init__(self):
        tk.Tk.__init__(self)
        self.title("Car Management System")

        # Create the main menu
        self.menu = tk.Menu(self)
        self.menu.add_command(label="Add Employee", command=self.open_add_employee)
        self.menu.add_command(label="Delete Employee", command=self.open_delete_employee)
        self.menu.add_command(label="Modify Employee", command=self.open_modify_employee)
        self.menu.add_command(label="Display Car Details", command=self.open_display_car_details)
        self.menu.add_command(label="Display Sales Details", command=self.open_display_sales_details)
        self.config(menu=self.menu)

    def open_add_employee(self):
        # Create a new window for adding an employee
        add_employee_window = tk.Toplevel(self)
        add_employee_window.title("Add Employee")

        # Create labels and entry fields for employee details
        label_name = tk.Label(add_employee_window, text="Name:")
        label_name.pack()
        entry_name = tk.Entry(add_employee_window)
        entry_name.pack()

        label_id = tk.Label(add_employee_window, text="ID Number:")
        label_id.pack()
        entry_id = tk.Entry(add_employee_window)
        entry_id.pack()

        label_department = tk.Label(add_employee_window, text="Department:")
        label_department.pack()
        entry_department = tk.Entry(add_employee_window)
        entry_department.pack()

        label_job_title = tk.Label(add_employee_window, text="Job Title:")
        label_job_title.pack()
        entry_job_title = tk.Entry(add_employee_window)
        entry_job_title.pack()

        label_basic_salary = tk.Label(add_employee_window, text="Basic Salary:")
        label_basic_salary.pack()
        entry_basic_salary = tk.Entry(add_employee_window)
        entry_basic_salary.pack()

        # Create a button to add the employee
        button_add_employee = tk.Button(add_employee_window, text="Add Employee",
                                        command=lambda: self.add_employee(entry_name.get(), entry_id.get(),
                                                                         entry_department.get(),
                                                                         entry_job_title.get(),
                                                                         entry_basic_salary.get()))
        button_add_employee.pack()

    def open_delete_employee(self):
        # Create a new window for deleting an employee
        delete_employee_window = tk.Toplevel(self)
        delete_employee_window.title("Delete Employee")

        # Create a label and entry field for the employee ID to delete
        label_id = tk.Label(delete_employee_window, text="ID Number:")
        label_id.pack()
        entry_id = tk.Entry(delete_employee_window)
        entry_id.pack()

        # Create a button to delete the employee
        button_delete_employee = tk.Button(delete_employee_window, text="Delete Employee",
                                           command=lambda: self.delete_employee(entry_id.get()))
        button_delete_employee.pack()

    def open_modify_employee(self):
        # Create a new window for modifying an employee
        modify_employee_window = tk.Toplevel(self)
        modify_employee_window.title("Modify Employee")
        # Create labels and entry fields for employee details
        label_id = tk.Label(modify_employee_window, text="ID Number:")
        label_id.pack()
        entry_id = tk.Entry(modify_employee_window)
        entry_id.pack()

        label_name = tk.Label(modify_employee_window, text="Name:")
        label_name.pack()
        entry_name = tk.Entry(modify_employee_window)
        entry_name.pack()

        label_department = tk.Label(modify_employee_window, text="Department:")
        label_department.pack()
        entry_department = tk.Entry(modify_employee_window)
        entry_department.pack()

        label_job_title = tk.Label(modify_employee_window, text="Job Title:")
        label_job_title.pack()
        entry_job_title = tk.Entry(modify_employee_window)
        entry_job_title.pack()

        label_basic_salary = tk.Label(modify_employee_window, text="Basic Salary:")
        label_basic_salary.pack()
        entry_basic_salary = tk.Entry(modify_employee_window)
        entry_basic_salary.pack()

        # Create a button to modify the employee
        button_modify_employee = tk.Button(modify_employee_window, text="Modify Employee",
                                           command=lambda: self.modify_employee(entry_id.get(), entry_name.get(),
                                                                                entry_department.get(),
                                                                                entry_job_title.get(),
                                                                                entry_basic_salary.get()))
        button_modify_employee.pack()

    def open_display_car_details(self):
        # Create a new window for displaying car details
        display_car_details_window = tk.Toplevel(self)
        display_car_details_window.title("Display Car Details")

        # Create a label and entry field for the car ID to display
        label_id = tk.Label(display_car_details_window, text="ID Number:")
        label_id.pack()
        entry_id = tk.Entry(display_car_details_window)
        entry_id.pack()

        # Create a button to display the car details
        button_display_car_details = tk.Button(display_car_details_window, text="Display Car Details",
                                               command=lambda: self.display_car_details(entry_id.get()))
        button_display_car_details.pack()

    def open_display_sales_details(self):
        # Create a new window for displaying sales details
        display_sales_details_window = tk.Toplevel(self)
        display_sales_details_window.title("Display Sales Details")

        # Create a label and entry field for the employee ID to display sales details
        label_id = tk.Label(display_sales_details_window, text="ID Number:")
        label_id.pack()
        entry_id = tk.Entry(display_sales_details_window)
        entry_id.pack()

        # Create a button to display the sales details
        button_display_sales_details = tk.Button(display_sales_details_window, text="Display Sales Details",
                                                 command=lambda: self.display_sales_details(entry_id.get()))
        button_display_sales_details.pack()

    def add_employee(self, name, id_number, department, job_title, basic_salary):
        # Create an Employee instance with the provided details
        employee = Employee(name, id_number, department, job_title, basic_salary)

        # Save the employee to a binary file using Pickle
        with open("employees.pkl", "ab") as file:
            pickle.dump(employee, file)

        # Show a success message
        tk.messagebox.showinfo("Success", "Employee added successfully.")

    def delete_employee(self, id_number):
        # Load the employees from the binary file
        employees = self.load_employees()

        # Find the employee with the provided ID number
        for employee in employees:
            if employee.id_number == id_number:
                # Remove the employee from the list
                employees.remove(employee)

                # Save the updated list back to the binary file
                self.save_employees(employees)

                # Show a success message
                tk.messagebox.showinfo
                tk.messagebox.showinfo("Success", "Employee deleted successfully.")
                return

        # Show an error message if the employee was not found
        tk.messagebox.showerror("Error", "Employee not found.")

    def modify_employee(self, id_number, name, department, job_title, basic_salary):
        # Load the employees from the binary file
        employees = self.load_employees()

        # Find the employee with the provided ID number
        for employee in employees:
            if employee.id_number == id_number:
                # Modify the employee details
                employee.name = name
                employee.department = department
                employee.job_title = job_title
                employee.basic_salary = basic_salary

                # Save the updated list back to the binary file
                self.save_employees(employees)

                # Show a success message
                tk.messagebox.showinfo("Success", "Employee modified successfully.")
                return

        # Show an error message if the employee was not found
        tk.messagebox.showerror("Error", "Employee not found.")

    def display_car_details(self, id_number):
        # Load the cars from the binary file
        cars = self.load_cars()

        # Find the car with the provided ID number
        for car in cars:
            if car.id_number == id_number:
                # Show the car details
                tk.messagebox.showinfo("Car Details", f"ID Number: {car.id_number}\nPrice: {car.price}\nType: {car.car_type}")
                return

        # Show an error message if the car was not found
        tk.messagebox.showerror("Error", "Car not found.")

    def display_sales_details(self, id_number):
        # Load the employees from the binary file
        employees = self.load_employees()

        # Find the employee with the provided ID number
        for employee in employees:
            if employee.id_number == id_number:
                # Show the sales details of the employee
                sales_details = ""
                for sale in employee.sales:
                    sales_details += f"Car Sold: {sale.car_name}\nSale Price: {sale.sale_price}\n\n"

                tk.messagebox.showinfo("Sales Details", sales_details)
                return

        # Show an error message if the employee was not found
        tk.messagebox.showerror("Error", "Employee not found.")

    def load_employees(self):
        # Load employees from the binary file
        try:
            with open("employees.pkl", "rb") as file:
                employees = []
                while True:
                    try:
                        employee = pickle.load(file)
                        employees.append(employee)
                    except EOFError:
                        break
                return employees
        except FileNotFoundError:
            return []

    def save_employees(self, employees):
        # Save employees to the binary file
        with open("employees.pkl", "wb") as file:
            for employee in employees:
                pickle.dump(employee, file)

    def load_cars(self):
        # Load cars from the binary file
        try:
            with open("cars.pkl", "rb") as file:
                cars = []
                while True:
                    try:
                        car = pickle.load(file)
                        cars.append(car)
                    except EOFError:
                        break
                return cars
        except FileNotFoundError:
            return []

    def save_cars(self, cars):
        # Save cars to the binary file
        with open("cars.pkl", "wb") as file:
            for car in cars:
                pickle.dump(car, file)

# Create the main window
if __name__ == "__main__":
    root = MainWindow()
    root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-1-def6e6236911> in <cell line: 291>()
#     290 # Create the main window
#     291 if __name__ == "__main__":
# --> 292     root = MainWindow()
#     293     root.mainloop()
#
# <ipython-input-1-def6e6236911> in __init__(self)
#      22 class MainWindow(tk.Tk):
#      23     def __init__(self):
# ---> 24         tk.Tk.__init__(self)
#      25         self.title("Car Management System")
#      26
#
# /usr/lib/python3.10/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2300                 baseName = baseName + ext
#    2301         interactive = False
# -> 2302         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2303         if useTk:
#    2304             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable

# %%
#code 1 : 

import tkinter as tk
from tkinter import messagebox
import pickle

class Employee:
    def __init__(self, name, id_number, department, job_title, basic_salary):
        self.name = name
        self.id_number = id_number
        self.department = department
        self.job_title = job_title
        self.basic_salary = basic_salary

class Car:
    def __init__(self, name, id_number, price, car_type):
        self.name = name
        self.id_number = id_number
        self.price = price
        self.car_type = car_type

def add_employee():
    name = entry_name.get()
    id_number = int(entry_id_number.get())
    department = entry_department.get()
    job_title = entry_job_title.get()
    basic_salary = float(entry_basic_salary.get())

    employee = Employee(name, id_number, department, job_title, basic_salary)
    save_to_file(employee, "employees.dat")
    messagebox.showinfo("Success", "Employee added successfully")

def delete_employee():
    id_number = int(entry_id_number.get())
    delete_from_file(id_number, "employees.dat")
    messagebox.showinfo("Success", "Employee deleted successfully")

def modify_employee():
    id_number = int(entry_id_number.get())
    name = entry_name.get()
    department = entry_department.get()
    job_title = entry_job_title.get()
    basic_salary = float(entry_basic_salary.get())

    employee = Employee(name, id_number, department, job_title, basic_salary)
    update_file(employee, "employees.dat")
    messagebox.showinfo("Success", "Employee modified successfully")

def display_car_details():
    id_number = int(entry_id_number.get())
    car = load_from_file(id_number, "cars.dat")
    if car:
        messagebox.showinfo("Car Details",
                            f"Name: {car.name}\nID Number: {car.id_number}\nPrice: {car.price}\nType: {car.car_type}")
    else:
        messagebox.showerror("Error", "Car not found")

def display_sales_details():
    id_number = int(entry_id_number.get())
    employee = load_from_file(id_number, "employees.dat")
    if employee:
        messagebox.showinfo("Sales Details",
                            f"Name: {employee.name}\nID Number: {employee.id_number}\nDepartment: {employee.department}\nJob Title: {employee.job_title}\nBasic Salary: {employee.basic_salary}")
    else:
        messagebox.showerror("Error", "Employee not found")

def save_to_file(data, filename):
    with open(filename, "ab") as file:
        pickle.dump(data, file)

def load_from_file(id_number, filename):
    with open(filename, "rb") as file:
        try:
            while True:
                data = pickle.load(file)
                if data.id_number == id_number:
                    return data
        except EOFError:
            return None

def delete_from_file(id_number, filename):
    temp_filename = "temp.dat"
    with open(filename, "rb") as source_file, open(temp_filename, "wb") as target_file:
        try:
            while True:
                data = pickle.load(source_file)
                if data.id_number != id_number:
                    pickle.dump(data, target_file)
        except EOFError:
            pass
    import os
    os.replace(temp_filename, filename)

def update_file(updated_data, filename):
    temp_filename = "temp.dat"
    with open(filename, "rb") as source_file, open(temp_filename, "wb") as target_file:
        try:
            while True:
                data = pickle.load
                data = pickle.load(source_file)
                if data.id_number != updated_data.id_number:
                    pickle.dump(data, target_file)
                else:
                    pickle.dump(updated_data, target_file)
        except EOFError:
            pass
    import os
    os.replace(temp_filename, filename)

# Create the GUI window
window = tk.Tk()
window.title("Car Sales Management System")

# Create labels and entry fields for employee details
label_name = tk.Label(window, text="Name:")
label_name.grid(row=0, column=0, sticky="e")
entry_name = tk.Entry(window)
entry_name.grid(row=0, column=1)

label_id_number = tk.Label(window, text="ID Number:")
label_id_number.grid(row=1, column=0, sticky="e")
entry_id_number = tk.Entry(window)
entry_id_number.grid(row=1, column=1)

label_department = tk.Label(window, text="Department:")
label_department.grid(row=2, column=0, sticky="e")
entry_department = tk.Entry(window)
entry_department.grid(row=2, column=1)

label_job_title = tk.Label(window, text="Job Title:")
label_job_title.grid(row=3, column=0, sticky="e")
entry_job_title = tk.Entry(window)
entry_job_title.grid(row=3, column=1)

label_basic_salary = tk.Label(window, text="Basic Salary:")
label_basic_salary.grid(row=4, column=0, sticky="e")
entry_basic_salary = tk.Entry(window)
entry_basic_salary.grid(row=4, column=1)

# Create buttons for employee operations
button_add_employee = tk.Button(window, text="Add Employee", command=add_employee)
button_add_employee.grid(row=5, column=0)

button_delete_employee = tk.Button(window, text="Delete Employee", command=delete_employee)
button_delete_employee.grid(row=5, column=1)

button_modify_employee = tk.Button(window, text="Modify Employee", command=modify_employee)
button_modify_employee.grid(row=5, column=2)

# Create labels and entry fields for car details
label_car_id = tk.Label(window, text="Car ID:")
label_car_id.grid(row=6, column=0, sticky="e")
entry_car_id = tk.Entry(window)
entry_car_id.grid(row=6, column=1)

# Create buttons for car operations
button_display_car_details = tk.Button(window, text="Display Car Details", command=display_car_details)
button_display_car_details.grid(row=7, column=0)

# Create buttons for sales operations
button_display_sales_details = tk.Button(window, text="Display Sales Details", command=display_sales_details)
button_display_sales_details.grid(row=7, column=1)

# Run the GUI window
window.mainloop()

# %%
import tkinter as tk
from tkinter import messagebox
import pickle
import os

class Employee:
    def __init__(self, id, name, position):
        self.id = id
        self.name = name
        self.position = position

class CarSalesGUI:
    def __init__(self):
        self.employees = self.load_employees()
        self.cars = self.load_cars()

        self.root = tk.Tk()
        self.root.title("Car Sales System")

        self.main_frame = tk.Frame(self.root)
        self.main_frame.pack(padx=20, pady=20)

        self.add_employee_button = tk.Button(self.main_frame, text="Add Employee", command=self.open_add_employee_window)
        self.add_employee_button.grid(row=0, column=0, padx=5, pady=5)

        self.modify_employee_button = tk.Button(self.main_frame, text="Modify Employee", command=self.open_modify_employee_window)
        self.modify_employee_button.grid(row=0, column=1, padx=5, pady=5)

        self.display_employee_button = tk.Button(self.main_frame, text="Display Employee", command=self.open_display_employee_window)
        self.display_employee_button.grid(row=0, column=2, padx=5, pady=5)

        self.root.mainloop()

    def load_employees(self):
        try:
            if os.path.exists('employees_data.pkl'):
                with open('employees_data.pkl', 'rb') as file:
                    return pickle.load(file)
        except FileNotFoundError:
            pass
        return []

    def save_employees(self):
        with open('employees_data.pkl', 'wb') as file:
            pickle.dump(self.employees, file)

    def open_add_employee_window(self):
        add_employee_window = tk.Toplevel(self.root)
        add_employee_window.title("Add Employee")

        # ... rest of the code ...

    def add_employee(self, id, name, position, add_employee_window):
        # ... rest of the code ...

    def open_modify_employee_window(self):
        modify_employee_window = tk.T
