# %%
class SystemGUI(tk.Tk):
    def __init__(self):
        super().__init__()

        self.title("System GUI")

        self.notebook = ttk.Notebook(self)

        # Create tabs for each class
        self.tab_company = ttk.Frame(self.notebook)
        self.tab_warehouse = ttk.Frame(self.notebook)
        self.tab_showroom = ttk.Frame(self.notebook)
        self.tab_person = ttk.Frame(self.notebook)
        self.tab_employee = ttk.Frame(self.notebook)
        self.tab_manager = ttk.Frame(self.notebook)
        self.tab_customer = ttk.Frame(self.notebook)
        self.tab_car = ttk.Frame(self.notebook)
        self.tab_sales = ttk.Frame(self.notebook)

        self.notebook.add(self.tab_company, text="Company")
        self.notebook.add(self.tab_warehouse, text="Warehouse")
        self.notebook.add(self.tab_showroom, text="Showroom")
        self.notebook.add(self.tab_person, text="Person")
        self.notebook.add(self.tab_employee, text="Employee")
        self.notebook.add(self.tab_manager, text="Manager")
        self.notebook.add(self.tab_customer, text="Customer")
        self.notebook.add(self.tab_car, text="Car")
        self.notebook.add(self.tab_sales, text="Sales")

        self.notebook.pack(expand=True, fill=tk.BOTH)

        # Create instances of your existing GUI classes and place them in the corresponding tabs
        self.company_gui = CompanyGUI(self.tab_company)
        self.company_gui.pack()

        self.warehouse_gui = WarehouseGUI(self.tab_warehouse)
        self.warehouse_gui.pack()

        self.showroom_gui = ShowroomGUI(self.tab_showroom)
        self.showroom_gui.pack()

        self.person_gui = PersonGUI(self.tab_person)
        self.person_gui.pack()

        self.employee_gui = EmployeeGUI(self.tab_employee)
        self.employee_gui.pack()

        self.manager_gui = ManagerGUI(self.tab_manager)
        self.manager_gui.pack()

        self.customer_gui = CustomerGUI(self.tab_customer)
        self.customer_gui.pack()

        self.car_gui = CarGUI(self.tab_car)
        self.car_gui.pack()

        self.sales_gui = SalesGUI(self.tab_sales)
        self.sales_gui.pack()


# Example usage
if __name__ == "__main__":
    root = SystemGUI()
    root.mainloop()

# %%
#Warehouse 



class WarehouseGUI(tk.Toplevel):
    def __init__(self, parent, warehouse):
        super().__init__(parent)
        self.warehouse = warehouse
        self.title("Warehouse")
        self.geometry("400x300")

        self.label_warehouse_id = tk.Label(self, text="Warehouse ID:")
        self.label_warehouse_id.pack()

        self.entry_warehouse_id = tk.Entry(self)
        self.entry_warehouse_id.pack()

        self.label_address = tk.Label(self, text="Address:")
        self.label_address.pack()

        self.entry_address = tk.Entry(self)
        self.entry_address.pack()

        self.label_capacity = tk.Label(self, text="Capacity:")
        self.label_capacity.pack()

        self.entry_capacity = tk.Entry(self)
        self.entry_capacity.pack()

        self.button_save = tk.Button(self, text="Save", command=self.save_warehouse)
        self.button_save.pack()

    def save_warehouse(self):
        warehouse_id = self.entry_warehouse_id.get()
        address = self.entry_address.get()
        capacity = self.entry_capacity.get()

        self.warehouse._warehouseID = warehouse_id
        self.warehouse._address = address
        self.warehouse._capacity = capacity

        messagebox.showinfo("Warehouse", "Warehouse information saved successfully!")


# Example usage
warehouse = Warehouse("W001", "123 Main St", 100)
root = tk.Tk()

def open_warehouse_gui():
    warehouse_gui = WarehouseGUI(root, warehouse)

button_open_warehouse_gui = tk.Button(root, text="Open Warehouse GUI", command=open_warehouse_gui)
button_open_warehouse_gui.pack()

root.mainloop()

# %%
#Showroom 



class ShowroomGUI(tk.Toplevel):
    def __init__(self, parent, showroom):
        super().__init__(parent)
        self.showroom = showroom
        self.title("Showroom")
        self.geometry("400x300")

        self.label_showroom_id = tk.Label(self, text="Showroom ID:")
        self.label_showroom_id.pack()

        self.entry_showroom_id = tk.Entry(self)
        self.entry_showroom_id.pack()

        self.label_address = tk.Label(self, text="Address:")
        self.label_address.pack()

        self.entry_address = tk.Entry(self)
        self.entry_address.pack()

        self.button_save = tk.Button(self, text="Save", command=self.save_showroom)
        self.button_save.pack()

    def save_showroom(self):
        showroom_id = self.entry_showroom_id.get()
        address = self.entry_address.get()

        self.showroom._showroomID = showroom_id
        self.showroom._address = address

        messagebox.showinfo("Showroom", "Showroom information saved successfully!")


# Example usage
showroom = Showroom("S001", "456 Elm St")
root = tk.Tk()

def open_showroom_gui():
    showroom_gui = ShowroomGUI(root, showroom)

button_open_showroom_gui = tk.Button(root, text="Open Showroom GUI", command=open_showroom_gui)
button_open_showroom_gui.pack()

root.mainloop()

# %%
#person 
class PersonGUI(tk.Toplevel):
    def __init__(self, parent, person):
        super().__init__(parent)
        self.person = person
        self.title("Person")
        self.geometry("400x400")

        self.label_first_name = tk.Label(self, text="First Name:")
        self.label_first_name.pack()

        self.entry_first_name = tk.Entry(self)
        self.entry_first_name.pack()

        self.label_last_name = tk.Label(self, text="Last Name:")
        self.label_last_name.pack()

        self.entry_last_name = tk.Entry(self)
        self.entry_last_name.pack()

        self.label_gender = tk.Label(self, text="Gender:")
        self.label_gender.pack()

        self.entry_gender = tk.Entry(self)
        self.entry_gender.pack()

        self.label_date_of_birth = tk.Label(self, text="Date of Birth:")
        self.label_date_of_birth.pack()

        self.entry_date_of_birth = tk.Entry(self)
        self.entry_date_of_birth.pack()

        self.label_contact_number = tk.Label(self, text="Contact Number:")
        self.label_contact_number.pack()

        self.entry_contact_number = tk.Entry(self)
        self.entry_contact_number.pack()

        self.label_email_address = tk.Label(self, text="Email Address:")
        self.label_email_address.pack()

        self.entry_email_address = tk.Entry(self)
        self.entry_email_address.pack()

        self.button_save = tk.Button(self, text="Save", command=self.save_person)
        self.button_save.pack()

    def save_person(self):
        first_name = self.entry_first_name.get()
        last_name = self.entry_last_name.get()
        gender = self.entry_gender.get()
        date_of_birth = self.entry_date_of_birth.get()
        contact_number = self.entry_contact_number.get()
        email_address = self.entry_email_address.get()

        self.person._firstName = first_name
        self.person._lastName = last_name
        self.person._gender = gender
        self.person._dateOfBirth = date_of_birth
        self.person._contactNumber = contact_number
        self.person._emailAddress = email_address

        messagebox.showinfo("Person", "Person information saved successfully!")


# Example usage
person = Person("John", "Doe", "Male", "1990-01-01", "1234567890", "john@example.com")
root = tk.Tk()


def open_person_gui():
    person_gui = PersonGUI(root, person)


button_open_person_gui = tk.Button(root, text="Open Person GUI", command=open_person_gui)
button_open_person_gui.pack()

root.mainloop()

# %%
#employee


class EmployeeGUI(tk.Frame):
    def __init__(self, master, employee):
        super().__init__(master)
        self.employee = employee

        self.label_id = tk.Label(self, text="Employee ID:")
        self.entry_id = tk.Entry(self)

        self.label_department = tk.Label(self, text="Department:")
        self.entry_department = tk.Entry(self)

        self.label_job_title = tk.Label(self, text="Job Title:")
        self.entry_job_title = tk.Entry(self)

        self.label_basic_salary = tk.Label(self, text="Basic Salary:")
        self.entry_basic_salary = tk.Entry(self)

        self.button_save_employee = tk.Button(self, text="Save", command=self.save_employee)

        self.label_id.pack()
        self.entry_id.pack()
        self.label_department.pack()
        self.entry_department.pack()
        self.label_job_title.pack()
        self.entry_job_title.pack()
        self.label_basic_salary.pack()
        self.entry_basic_salary.pack()
        self.button_save_employee.pack()

        self.pack()

    def save_employee(self):
        employee_id = self.entry_id.get()
        department = self.entry_department.get()
        job_title = self.entry_job_title.get()
        basic_salary = self.entry_basic_salary.get()

        if not employee_id or not department or not job_title or not basic_salary:
            messagebox.showerror("Error", "Please enter all the fields.")
            return

        self.employee._ID = employee_id
        self.employee._department = department
        self.employee._jobTitle = job_title
        self.employee._basicSalary = basic_salary

        messagebox.showinfo("Employee", "Employee information saved successfully!")


# Example usage
person = Person("John", "Doe", "Male", "1990-01-01", "1234567890", "john@example.com")
employee = Employee("John", "Doe", "Male", "1990-01-01", "1234567890", "john@example.com",
                    "EMP001", "IT", "Developer", "5000")
root = tk.Tk()


def open_employee_gui():
    employee_gui = EmployeeGUI(root, employee)


button_open_employee_gui = tk.Button(root, text="Open Employee GUI", command=open_employee_gui)
button_open_employee_gui.pack()

root.mainloop()

# %%
#manager 


class ManagerGUI(tk.Frame):
    def __init__(self, master, manager):
        super().__init__(master)
        self.manager = manager

        self.label_id = tk.Label(self, text="Employee ID:")
        self.entry_id = tk.Entry(self)

        self.label_department = tk.Label(self, text="Department:")
        self.entry_department = tk.Entry(self)

        self.label_job_title = tk.Label(self, text="Job Title:")
        self.entry_job_title = tk.Entry(self)

        self.label_basic_salary = tk.Label(self, text="Basic Salary:")
        self.entry_basic_salary = tk.Entry(self)

        self.button_save_manager = tk.Button(self, text="Save", command=self.save_manager)

        self.label_id.pack()
        self.entry_id.pack()
        self.label_department.pack()
        self.entry_department.pack()
        self.label_job_title.pack()
        self.entry_job_title.pack()
        self.label_basic_salary.pack()
        self.entry_basic_salary.pack()
        self.button_save_manager.pack()

        self.pack()

    def save_manager(self):
        employee_id = self.entry_id.get()
        department = self.entry_department.get()
        job_title = self.entry_job_title.get()
        basic_salary = self.entry_basic_salary.get()

        if not employee_id or not department or not job_title or not basic_salary:
            messagebox.showerror("Error", "Please enter all the fields.")
            return

        self.manager._ID = employee_id
        self.manager._department = department
        self.manager._jobTitle = job_title
        self.manager._basicSalary = basic_salary

        messagebox.showinfo("Manager", "Manager information saved successfully!")


# Example usage
person = Person("John", "Doe", "Male", date(1990, 1, 1), "1234567890", "john@example.com")
manager = Manager("John", "Doe", "Male", date(1990, 1, 1), "1234567890", "john@example.com",
                  "MGR001", "Sales", "Manager", "7000")
root = tk.Tk()


def open_manager_gui():
    manager_gui = ManagerGUI(root, manager)


button_open_manager_gui = tk.Button(root, text="Open Manager GUI", command=open_manager_gui)
button_open_manager_gui.pack()

root.mainloop()

# %%
#customer

class CustomerGUI(tk.Frame):
    def __init__(self, master, customer):
        super().__init__(master)
        self.customer = customer

        self.label_first_name = tk.Label(self, text="First Name:")
        self.entry_first_name = tk.Entry(self)

        self.label_last_name = tk.Label(self, text="Last Name:")
        self.entry_last_name = tk.Entry(self)

        self.label_gender = tk.Label(self, text="Gender:")
        self.entry_gender = tk.Entry(self)

        self.label_date_of_birth = tk.Label(self, text="Date of Birth:")
        self.entry_date_of_birth = tk.Entry(self)

        self.label_contact_number = tk.Label(self, text="Contact Number:")
        self.entry_contact_number = tk.Entry(self)

        self.label_email_address = tk.Label(self, text="Email Address:")
        self.entry_email_address = tk.Entry(self)

        self.button_save_customer = tk.Button(self, text="Save", command=self.save_customer)

        self.label_first_name.pack()
        self.entry_first_name.pack()
        self.label_last_name.pack()
        self.entry_last_name.pack()
        self.label_gender.pack()
        self.entry_gender.pack()
        self.label_date_of_birth.pack()
        self.entry_date_of_birth.pack()
        self.label_contact_number.pack()
        self.entry_contact_number.pack()
        self.label_email_address.pack()
        self.entry_email_address.pack()
        self.button_save_customer.pack()

        self.pack()

    def save_customer(self):
        first_name = self.entry_first_name.get()
        last_name = self.entry_last_name.get()
        gender = self.entry_gender.get()
        date_of_birth = self.entry_date_of_birth.get()
        contact_number = self.entry_contact_number.get()
        email_address = self.entry_email_address.get()

        if not first_name or not last_name or not gender or not date_of_birth or not contact_number or not email_address:
            messagebox.showerror("Error", "Please enter all the fields.")
            return

        self.customer._firstName = first_name
        self.customer._lastName = last_name
        self.customer._gender = gender
        self.customer._dateOfBirth = date_of_birth
        self.customer._contactNumber = contact_number
        self.customer._emailAddress = email_address

        messagebox.showinfo("Customer", "Customer information saved successfully!")


# Example usage
customer = Customer("John", "Doe", "Male", "1990-01-01", "1234567890", "john@example.com")
root = tk.Tk()


def open_customer_gui():
    customer_gui = CustomerGUI(root, customer)


button_open_customer_gui = tk.Button(root, text="Open Customer GUI", command=open_customer_gui)
button_open_customer_gui.pack()

root.mainloop()

# %%
#Car 



# GUI Implementation
class CarInventoryGUI:
    def __init__(self):
        self.window = tk.Tk()
        self.window.title("Car Inventory")
        
        # Create labels
        self.car_id_label = tk.Label(self.window, text="Car ID:")
        self.price_label = tk.Label(self.window, text="Price:")
        self.car_type_label = tk.Label(self.window, text="Car Type:")
        self.color_label = tk.Label(self.window, text="Color:")
        self.mileage_label = tk.Label(self.window, text="Mileage:")

        # Create entry fields
        self.car_id_entry = tk.Entry(self.window)
        self.price_entry = tk.Entry(self.window)
        self.car_type_entry = tk.Entry(self.window)
        self.color_entry = tk.Entry(self.window)
        self.mileage_entry = tk.Entry(self.window)

        # Create button
        self.add_car_button = tk.Button(self.window, text="Add Car", command=self.add_car)

        # Grid layout
        self.car_id_label.grid(row=0, column=0)
        self.price_label.grid(row=1, column=0)
        self.car_type_label.grid(row=2, column=0)
        self.color_label.grid(row=3, column=0)
        self.mileage_label.grid(row=4, column=0)
        self.car_id_entry.grid(row=0, column=1)
        self.price_entry.grid(row=1, column=1)
        self.car_type_entry.grid(row=2, column=1)
        self.color_entry.grid(row=3, column=1)
        self.mileage_entry.grid(row=4, column=1)
        self.add_car_button.grid(row=5, column=0, columnspan=2)

    def add_car(self):
        car_id = self.car_id_entry.get()
        price = self.price_entry.get()
        car_type = self.car_type_entry.get()
        color = self.color_entry.get()
        mileage = self.mileage_entry.get()

        # Create a new Car object
        car = Car(car_id, price, car_type, color, mileage)

        # Perform additional actions with the car object (e.g., add it to the inventory)

        # Display a success message
        messagebox.showinfo("Success", "Car added successfully!")

    def run(self):
        self.window.mainloop()

# Run the GUI
car_inventory_gui = CarInventoryGUI()
car_inventory_gui.run()

# %%
#Sales 


class SalesGUI(tk.Frame):
    def __init__(self, master, sales):
        super().__init__(master)
        self.sales = sales

        self.label_employee_id = tk.Label(self, text="Employee ID:")
        self.entry_employee_id = tk.Entry(self)

        self.label_sales_date = tk.Label(self, text="Sales Date:")
        self.entry_sales_date = tk.Entry(self)

        self.label_car_id = tk.Label(self, text="Car ID:")
        self.entry_car_id = tk.Entry(self)

        self.button_save_sales = tk.Button(self, text="Save", command=self.save_sales)

        self.label_employee_id.pack()
        self.entry_employee_id.pack()
        self.label_sales_date.pack()
        self.entry_sales_date.pack()
        self.label_car_id.pack()
        self.entry_car_id.pack()
        self.button_save_sales.pack()

        self.pack()

    def save_sales(self):
        employee_id = self.entry_employee_id.get()
        sales_date = self.entry_sales_date.get()
        car_id = self.entry_car_id.get()

        if not employee_id or not sales_date or not car_id:
            messagebox.showerror("Error", "Please enter all the fields.")
            return

        # Create a new Sales object
        sales = Sales(employee_id, sales_date, car_id)

        messagebox.showinfo("Sales", "Sales information saved successfully!")


# Example usage
root = tk.Tk()


def open_sales_gui():
    sales_gui = SalesGUI(root)


button_open_sales_gui = tk.Button(root, text="Open Sales GUI", command=open_sales_gui)
button_open_sales_gui.pack()

root.mainloop()

# %%
class Company:
    def __init__(self, name, address, phone):
        self._name = name
        self._address = address
        self._phone = phone
        self._warehouses = []
        self._showrooms = []

  
class Warehouse:
    def __init__(self, warehouseID, address, capacity):
        self._warehouseID = warehouseID
        self._address = address
        self._capacity = capacity
        self._cars = []
        self._staff = []
        self._manager = None

class Showroom:
    def __init__(self, showroomID, address):
        self._showroomID = showroomID
        self._address = address
        self._cars = []
        self._staff = []
        self._manager = None

class Person:
    def __init__(self, firstName,lastName, gender, dateOfBirth, contactNumber, emailAddress):
        self._firstName = firstName
        self._lastName = lastName
        self._gender = gender
        self._dateOfBirth = dateOfBirth
        self._contactNumber = contactNumber
        self._emailAddress = emailAddress
        self._age = self.calculateAge()
    
 
class Employee(Person):
    def __init__(self,firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress, ID, department, jobTitle, basicSalary):
        super().__init__(firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress)
        self._ID = ID
        self._department = department
        self._jobTitle = jobTitle
        self._basicSalary = basicSalary
        self._customers = []


class Manager(Employee):
    def __init__(self,firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress, ID, department, jobTitle, basicSalary):
        super().__init__(firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress, ID, department, jobTitle, basicSalary)
        self._salespersons = []

 

class Customer(Person):
    def __init__(self,firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress):
        super().__init__(firstName,lastName, gender, dateOfBirth,contactNumber, emailAddress)
        self._needs = ""
        self._budgetRange = 0
        self._salesperson = None


    def receipt(self, sale):
        car = sale._car
        salesperson_name = f"{self._salesperson._firstName} {self._salesperson._lastName}" if self._salesperson else "Not assigned"

        vat = car._price * 0.05  # Assuming VAT is 5% of the car price
        total_amount = car._price + vat

        receipt_details = f"Customer: {self._firstName} {self._lastName}\n" \
                          f"Salesperson: {salesperson_name}\n" \
                          f"Car: {car._carID}\n" \
                          f"Price: ${car._price}\n" \
                          f"VAT: ${vat}\n" \
                          f"Total Amount: ${total_amount}\n"

        return receipt_details

class Car:
    def __init__(self, carID, price, carType, fuelCapacity, maxSpeed, color, mileage, is_new):
        self._carID = carID
        self._price = price
        self._carType = carType
        self._fuelCapacity = fuelCapacity
        self._maxSpeed = maxSpeed
        self._color = color
        self._mileage = mileage
        self._is_new = is_new

class Sales:
    salesRecords = []
    
    def __init__(self, employeeID, salesDate, car):
        self._employeeID = employeeID
        self._salesDate = salesDate
        self._car = car 
        Sales.salesRecords.append(self)

    
    @classmethod
    def getSalesByEmployeeID(cls, employeeID):
        employeeSales = [sale for sale in cls.salesRecords if sale.employeeID == employeeID]
        return employeeSales

    def calculateCommission(self):
        salespersonCommission = self._car._price * 0.065
        managerCommission = self._car._price * 0.035
        companyShare = self._car._price - salespersonCommission - managerCommission
        return salespersonCommission, managerCommission, companyShare
